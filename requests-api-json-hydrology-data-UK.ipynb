# %% [markdown]
# ## Import package libraries

# %%
import requests
import json

# %% [markdown]
# ### Using the EA hydrology API
# https://environment.data.gov.uk/hydrology/doc/reference

# %%
# Obtain available stations
response = requests.get('http://environment.data.gov.uk/hydrology/id/stations')

# %%
# Check the request worked (code = 200). If 404 request failed.
response.status_code
# Out:
# 200

# %%
# View response in json format
response.json()
# Out:
# {'meta': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations',
#   'publisher': 'Environment Agency',
#   'license': 'http://www.nationalarchives.gov.uk/doc/open-government-licence/version/3/',
#   'licenseName': 'OGL 3',
#   'comment': 'Test version of hydrology API, alpha',
#   'version': '0.2.0',
#   'hasFormat': ['http://environment.data.gov.uk/hydrology/id/stations.ttl',
#    'http://environment.data.gov.uk/hydrology/id/stations.csv',
#    'http://environment.data.gov.uk/hydrology/id/stations.html',
#    'http://environment.data.gov.uk/hydrology/id/stations.rdf',
#    'http://environment.data.gov.uk/hydrology/id/stations.geojson']},
#  'items': [{'@id': 'http://environment.data.gov.uk/hydrology/id/stations/f9fcfbc0-af1b-46f6-bf20-6d8aedc1c72f',
#    'label': 'GRIBBLEFORD BRIDGE',
#    'notation': 'f9fcfbc0-af1b-46f6-bf20-6d8aedc1c72f',
#    'easting': 252770,
#    'northing': 101392,
#    'lat': 50.793341,
#    'long': -4.090328,
#    'type': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/def/core/Station'},
#     {'@id': 'http://environment.data.gov.uk/reference/def/core/SamplingLocation'}],
#    'riverName': 'River Lew',
#    'stationReference': '50121',
#    'wiskiID': 'SS50F007',
#    'RLOIid': '3121',
#    'measures': [{'@id': 'http://environment.data.gov.uk/hydrology/id/measures/f9fcfbc0-af1b-46f6-bf20-6d8aedc1c72f-flow-m-86400-m3s-qualified',
#      'label': 'Qualified daily mean flow timeseries for SS50F007(GRIBBLEFORD BRIDGE)',
#      'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#       'label': 'Water Flow'},
#      'unitName': 'm3/s',
#      'notation': 'f9fcfbc0-af1b-46f6-bf20-6d8aedc1c72f-flow-m-86400-m3s-qualified',
#      'period': 86400,
#      'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#       'label': 'mean'},
#      'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#       'label': 'Qualified'}},
#     {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/f9fcfbc0-af1b-46f6-bf20-6d8aedc1c72f-flow--i-15_min-m3_s-measured',
#      'label': 'Measured flow 15 min timeseries for Gribbleford',
#      'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#       'label': 'Water Flow'},
#      'unitName': 'm3/s',
#      'notation': 'f9fcfbc0-af1b-46f6-bf20-6d8aedc1c72f-flow--i-15_min-m3_s-measured',
#      'period': 900,
#      'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#       'label': 'mean'},
#      'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Measured',
#       'label': 'Measured'}}]},
#   {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/736dd802-46b4-4864-ae7e-9c470d21ad46',
#    'label': 'JACOBSTOWE',
#    'notation': '736dd802-46b4-4864-ae7e-9c470d21ad46',
#    'easting': 259185,
#    'northing': 101918,
#    'lat': 50.799663,
#    'long': -3.999571,
#    'type': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/def/core/Station'},
#     {'@id': 'http://environment.data.gov.uk/reference/def/core/SamplingLocation'}],
#    'riverName': 'River Okement',
#    'stationReference': '50120',
#    'wiskiID': 'SS50F042',
#    'RLOIid': '3122',
#    'measures': {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/736dd802-46b4-4864-ae7e-9c470d21ad46-flow-m-86400-m3s-qualified',
#     'label': 'Qualified daily mean flow timeseries for SS50F042(JACOBSTOWE)',
#     'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#      'label': 'Water Flow'},
#     'unitName': 'm3/s',
#     'notation': '736dd802-46b4-4864-ae7e-9c470d21ad46-flow-m-86400-m3s-qualified',
#     'period': 86400,
#     'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#      'label': 'mean'},
#     'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#      'label': 'Qualified'}}},
#   {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/d2d2a44c-25cb-4b0d-b4a5-4929e1d11975',
#    'label': 'TORRINGTON',
#    'notation': 'd2d2a44c-25cb-4b0d-b4a5-4929e1d11975',
#    'easting': 249955,
#    'northing': 118564,
#    'lat': 50.946929,
#    'long': -4.137288,
#    'type': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/def/core/Station'},
#     {'@id': 'http://environment.data.gov.uk/reference/def/core/SamplingLocation'}],
#    'riverName': 'River Torridge',
#    'stationReference': '50116',
#    'wiskiID': 'SS51F004',
#    'RLOIid': '3126',
#    'measures': [{'@id': 'http://environment.data.gov.uk/hydrology/id/measures/d2d2a44c-25cb-4b0d-b4a5-4929e1d11975-flow-m-86400-m3s-qualified',
#      'label': 'Qualified daily mean flow timeseries for SS51F004(TORRINGTON)',
#      'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#       'label': 'Water Flow'},
#      'unitName': 'm3/s',
#      'notation': 'd2d2a44c-25cb-4b0d-b4a5-4929e1d11975-flow-m-86400-m3s-qualified',
#      'period': 86400,
#      'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#       'label': 'mean'},
#      'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#       'label': 'Qualified'}},
#     {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/d2d2a44c-25cb-4b0d-b4a5-4929e1d11975-flow--i-15_min-m3_s-measured',
#      'label': 'Measured flow 15 min timeseries for Torrington',
#      'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#       'label': 'Water Flow'},
#      'unitName': 'm3/s',
#      'notation': 'd2d2a44c-25cb-4b0d-b4a5-4929e1d11975-flow--i-15_min-m3_s-measured',
#      'period': 900,
#      'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#       'label': 'mean'},
#      'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Measured',
#       'label': 'Measured'}}]},
#   {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/b7db631d-9aa8-49c1-9a61-b2824d0b42c8',
#    'label': 'TAW BRIDGE',
#    'notation': 'b7db631d-9aa8-49c1-9a61-b2824d0b42c8',
#    'easting': 267293,
#    'northing': 106820,
#    'lat': 50.845636,
#    'long': -3.88636,
#    'type': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/def/core/Station'},
#     {'@id': 'http://environment.data.gov.uk/reference/def/core/SamplingLocation'}],
#    'riverName': 'River Taw',
#    'stationReference': '50119',
#    'wiskiID': 'SS60F015',
#    'RLOIid': '3123',
#    'measures': {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/b7db631d-9aa8-49c1-9a61-b2824d0b42c8-flow-m-86400-m3s-qualified',
#     'label': 'Qualified daily mean flow timeseries for SS60F015(TAW BRIDGE)',
#     'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#      'label': 'Water Flow'},
#     'unitName': 'm3/s',
#     'notation': 'b7db631d-9aa8-49c1-9a61-b2824d0b42c8-flow-m-86400-m3s-qualified',
#     'period': 86400,
#     'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#      'label': 'mean'},
#     'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#      'label': 'Qualified'}}},
#   {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/fafd42b9-ed79-459c-98a6-83b7692eab78',
#    'label': 'UMBERLEIGH',
#    'notation': 'fafd42b9-ed79-459c-98a6-83b7692eab78',
#    'easting': 260795,
#    'northing': 123662,
#    'lat': 50.995466,
#    'long': -3.985034,
#    'type': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/def/core/Station'},
#     {'@id': 'http://environment.data.gov.uk/reference/def/core/SamplingLocation'}],
#    'riverName': 'River Taw',
#    'stationReference': '50140',
#    'wiskiID': 'SS62F001',
#    'RLOIid': '3106',
#    'measures': [{'@id': 'http://environment.data.gov.uk/hydrology/id/measures/fafd42b9-ed79-459c-98a6-83b7692eab78-flow--i-15_min-m3_s-measured',
#      'label': 'Measured flow 15 min timeseries for Umberleigh',
#      'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#       'label': 'Water Flow'},
#      'unitName': 'm3/s',
#      'notation': 'fafd42b9-ed79-459c-98a6-83b7692eab78-flow--i-15_min-m3_s-measured',
#      'period': 900,
#      'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#       'label': 'mean'},
#      'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Measured',
#       'label': 'Measured'}},
#     {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/fafd42b9-ed79-459c-98a6-83b7692eab78-flow-m-86400-m3s-qualified',
#      'label': 'Qualified daily mean flow timeseries for SS62F001(UMBERLEIGH)',
#      'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#       'label': 'Water Flow'},
#      'unitName': 'm3/s',
#      'notation': 'fafd42b9-ed79-459c-98a6-83b7692eab78-flow-m-86400-m3s-qualified',
#      'period': 86400,
#      'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#       'label': 'mean'},
#      'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#       'label': 'Qualified'}}]},
#   {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/c001fee0-4166-478c-ba13-f7a38b325012',
#    'label': 'WOODLEIGH',
#    'notation': 'c001fee0-4166-478c-ba13-f7a38b325012',
#    'easting': 266011,
#    'northing': 121039,
#    'lat': 50.973131,
#    'long': -3.909783,
#    'type': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/def/core/Station'},
#     {'@id': 'http://environment.data.gov.uk/reference/def/core/SamplingLocation'}],
#    'riverName': 'River Mole',
#    'stationReference': '50115',
#    'wiskiID': 'SS62F002',
#    'RLOIid': '3127',
#    'measures': [{'@id': 'http://environment.data.gov.uk/hydrology/id/measures/c001fee0-4166-478c-ba13-f7a38b325012-flow--i-15_min-m3_s-measured',
#      'label': 'Measured flow 15 min timeseries for Woodleigh',
#      'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#       'label': 'Water Flow'},
#      'unitName': 'm3/s',
#      'notation': 'c001fee0-4166-478c-ba13-f7a38b325012-flow--i-15_min-m3_s-measured',
#      'period': 900,
#      'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#       'label': 'mean'},
#      'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Measured',
#       'label': 'Measured'}},
#     {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/c001fee0-4166-478c-ba13-f7a38b325012-flow-m-86400-m3s-qualified',
#      'label': 'Qualified daily mean flow timeseries for SS62F002(WOODLEIGH)',
#      'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#       'label': 'Water Flow'},
#      'unitName': 'm3/s',
#      'notation': 'c001fee0-4166-478c-ba13-f7a38b325012-flow-m-86400-m3s-qualified',
#      'period': 86400,
#      'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#       'label': 'mean'},
#      'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#       'label': 'Qualified'}}]},
#   {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/1c1c7743-d410-49e6-a57c-4bfa9097eac7',
#    'label': 'LEEHAMFORD BRIDGE',
#    'notation': '1c1c7743-d410-49e6-a57c-4bfa9097eac7',
#    'easting': 267727,
#    'northing': 139915,
#    'lat': 51.143171,
#    'long': -3.892262,
#    'type': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/def/core/Station'},
#     {'@id': 'http://environment.data.gov.uk/reference/def/core/SamplingLocation'}],
#    'riverName': 'River Bray',
#    'stationReference': '50130',
#    'wiskiID': 'SS63F015',
#    'measures': [{'@id': 'http://environment.data.gov.uk/hydrology/id/measures/1c1c7743-d410-49e6-a57c-4bfa9097eac7-flow-m-86400-m3s-qualified',
#      'label': 'Qualified daily mean flow timeseries for SS63F015(LEEHAMFORD BRIDGE)',
#      'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#       'label': 'Water Flow'},
#      'unitName': 'm3/s',
#      'notation': '1c1c7743-d410-49e6-a57c-4bfa9097eac7-flow-m-86400-m3s-qualified',
#      'period': 86400,
#      'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#       'label': 'mean'},
#      'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#       'label': 'Qualified'}},
#     {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/1c1c7743-d410-49e6-a57c-4bfa9097eac7-flow--i-15_min-m3_s-measured',
#      'label': 'Measured flow 15 min timeseries for Leehamford',
#      'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#       'label': 'Water Flow'},
#      'unitName': 'm3/s',
#      'notation': '1c1c7743-d410-49e6-a57c-4bfa9097eac7-flow--i-15_min-m3_s-measured',
#      'period': 900,
#      'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#       'label': 'mean'},
#      'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Measured',
#       'label': 'Measured'}}]},
#   {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/3c4d4f78-2d0e-474a-b884-65a9daca18fb',
#    'label': 'THORVERTON',
#    'notation': '3c4d4f78-2d0e-474a-b884-65a9daca18fb',
#    'easting': 293602,
#    'northing': 101602,
#    'lat': 50.804172,
#    'long': -3.511302,
#    'type': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/def/core/Station'},
#     {'@id': 'http://environment.data.gov.uk/reference/def/core/SamplingLocation'}],
#    'riverName': 'River Exe',
#    'stationReference': '45118',
#    'wiskiID': 'SS90F011',
#    'RLOIid': '3260',
#    'measures': [{'@id': 'http://environment.data.gov.uk/hydrology/id/measures/3c4d4f78-2d0e-474a-b884-65a9daca18fb-flow--i-15_min-m3_s-measured',
#      'label': 'Measured flow 15 min timeseries for Thorverton',
#      'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#       'label': 'Water Flow'},
#      'unitName': 'm3/s',
#      'notation': '3c4d4f78-2d0e-474a-b884-65a9daca18fb-flow--i-15_min-m3_s-measured',
#      'period': 900,
#      'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#       'label': 'mean'},
#      'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Measured',
#       'label': 'Measured'}},
#     {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/3c4d4f78-2d0e-474a-b884-65a9daca18fb-flow-m-86400-m3s-qualified',
#      'label': 'Qualified daily mean flow timeseries for SS90F011(THORVERTON)',
#      'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#       'label': 'Water Flow'},
#      'unitName': 'm3/s',
#      'notation': '3c4d4f78-2d0e-474a-b884-65a9daca18fb-flow-m-86400-m3s-qualified',
#      'period': 86400,
#      'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#       'label': 'mean'},
#      'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#       'label': 'Qualified'}}]},
#   {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/33b613be-70df-4574-893e-f54443627dc1',
#    'label': 'STOODLEIGH',
#    'notation': '33b613be-70df-4574-893e-f54443627dc1',
#    'easting': 294281,
#    'northing': 117801,
#    'lat': 50.949913,
#    'long': -3.506358,
#    'type': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/def/core/Station'},
#     {'@id': 'http://environment.data.gov.uk/reference/def/core/SamplingLocation'}],
#    'riverName': 'River Exe',
#    'stationReference': '45120',
#    'wiskiID': 'SS91F008',
#    'RLOIid': '3258',
#    'measures': [{'@id': 'http://environment.data.gov.uk/hydrology/id/measures/33b613be-70df-4574-893e-f54443627dc1-flow-m-86400-m3s-qualified',
#      'label': 'Qualified daily mean flow timeseries for SS91F008(STOODLEIGH)',
#      'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#       'label': 'Water Flow'},
#      'unitName': 'm3/s',
#      'notation': '33b613be-70df-4574-893e-f54443627dc1-flow-m-86400-m3s-qualified',
#      'period': 86400,
#      'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#       'label': 'mean'},
#      'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#       'label': 'Qualified'}},
#     {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/33b613be-70df-4574-893e-f54443627dc1-flow--i-15_min-m3_s-measured',
#      'label': 'Measured flow 15 min timeseries for Stoodleigh',
#      'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#       'label': 'Water Flow'},
#      'unitName': 'm3/s',
#      'notation': '33b613be-70df-4574-893e-f54443627dc1-flow--i-15_min-m3_s-measured',
#      'period': 900,
#      'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#       'label': 'mean'},
#      'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Measured',
#       'label': 'Measured'}}]},
#   {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/4b146acd-5118-4e14-b23a-13405168a010',
#    'label': 'BRUSHFORD',
#    'notation': '4b146acd-5118-4e14-b23a-13405168a010',
#    'easting': 292695,
#    'northing': 125832,
#    'lat': 51.021811,
#    'long': -3.531302,
#    'type': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/def/core/Station'},
#     {'@id': 'http://environment.data.gov.uk/reference/def/core/SamplingLocation'}],
#    'riverName': 'River Barle',
#    'stationReference': '45121',
#    'wiskiID': 'SS92F008',
#    'RLOIid': '3257',
#    'measures': [{'@id': 'http://environment.data.gov.uk/hydrology/id/measures/4b146acd-5118-4e14-b23a-13405168a010-flow-m-86400-m3s-qualified',
#      'label': 'Qualified daily mean flow timeseries for SS92F008(BRUSHFORD)',
#      'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#       'label': 'Water Flow'},
#      'unitName': 'm3/s',
#      'notation': '4b146acd-5118-4e14-b23a-13405168a010-flow-m-86400-m3s-qualified',
#      'period': 86400,
#      'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#       'label': 'mean'},
#      'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#       'label': 'Qualified'}},
#     {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/4b146acd-5118-4e14-b23a-13405168a010-flow--i-15_min-m3_s-measured',
#      'label': 'Measured flow 15 min timeseries for BRUSHFORD',
#      'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#       'label': 'Water Flow'},
#      'unitName': 'm3/s',
#      'notation': '4b146acd-5118-4e14-b23a-13405168a010-flow--i-15_min-m3_s-measured',
#      'period': 900,
#      'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#       'label': 'mean'},
#      'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Measured',
#       'label': 'Measured'}}]},
#   {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/34202203-d1dc-4812-843a-715467152795',
#    'label': 'PIXTON',
#    'notation': '34202203-d1dc-4812-843a-715467152795',
#    'easting': 293493,
#    'northing': 125960,
#    'lat': 51.02311,
#    'long': -3.519966,
#    'type': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/def/core/Station'},
#     {'@id': 'http://environment.data.gov.uk/reference/def/core/SamplingLocation'}],
#    'riverName': 'River Exe',
#    'stationReference': '45122',
#    'wiskiID': 'SS92F014',
#    'RLOIid': '3256',
#    'measures': {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/34202203-d1dc-4812-843a-715467152795-flow-m-86400-m3s-qualified',
#     'label': 'Qualified daily mean flow timeseries for SS92F014(PIXTON)',
#     'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#      'label': 'Water Flow'},
#     'unitName': 'm3/s',
#     'notation': '34202203-d1dc-4812-843a-715467152795-flow-m-86400-m3s-qualified',
#     'period': 86400,
#     'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#      'label': 'mean'},
#     'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#      'label': 'Qualified'}}},
#   {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/cf5d2388-a6ea-4dab-9be1-6fef42fbc66a',
#    'label': 'WIMBLEBALL COMPENSATION',
#    'notation': 'cf5d2388-a6ea-4dab-9be1-6fef42fbc66a',
#    'easting': 296417,
#    'northing': 129401,
#    'lat': 51.054576,
#    'long': -3.479275,
#    'type': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/def/core/Station'},
#     {'@id': 'http://environment.data.gov.uk/reference/def/core/SamplingLocation'}],
#    'riverName': 'River Haddeo',
#    'stationReference': '45129',
#    'wiskiID': 'SS92F053',
#    'measures': [{'@id': 'http://environment.data.gov.uk/hydrology/id/measures/cf5d2388-a6ea-4dab-9be1-6fef42fbc66a-flow-m-86400-m3s-qualified',
#      'label': 'Qualified daily mean flow timeseries for SS92F053(WIMBLEBALL COMPENSATION)',
#      'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#       'label': 'Water Flow'},
#      'unitName': 'm3/s',
#      'notation': 'cf5d2388-a6ea-4dab-9be1-6fef42fbc66a-flow-m-86400-m3s-qualified',
#      'period': 86400,
#      'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#       'label': 'mean'},
#      'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#       'label': 'Qualified'}},
#     {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/cf5d2388-a6ea-4dab-9be1-6fef42fbc66a-flow--i-15_min-m3_s-measured',
#      'label': 'Measured flow 15 min timeseries for Wimbleball',
#      'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#       'label': 'Water Flow'},
#      'unitName': 'm3/s',
#      'notation': 'cf5d2388-a6ea-4dab-9be1-6fef42fbc66a-flow--i-15_min-m3_s-measured',
#      'period': 900,
#      'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#       'label': 'mean'},
#      'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Measured',
#       'label': 'Measured'}}]},
#   {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/d2dcdeb9-5c08-471b-8d86-e0e1bc1d4c9c',
#    'label': 'WOODMILL',
#    'notation': 'd2dcdeb9-5c08-471b-8d86-e0e1bc1d4c9c',
#    'easting': 302066,
#    'northing': 105773,
#    'lat': 50.843162,
#    'long': -3.39234,
#    'type': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/def/core/Station'},
#     {'@id': 'http://environment.data.gov.uk/reference/def/core/SamplingLocation'}],
#    'riverName': 'River Culm',
#    'stationReference': '45119',
#    'wiskiID': 'ST00F008',
#    'RLOIid': '3259',
#    'measures': {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/d2dcdeb9-5c08-471b-8d86-e0e1bc1d4c9c-flow-m-86400-m3s-qualified',
#     'label': 'Qualified daily mean flow timeseries for ST00F008(WOODMILL)',
#     'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#      'label': 'Water Flow'},
#     'unitName': 'm3/s',
#     'notation': 'd2dcdeb9-5c08-471b-8d86-e0e1bc1d4c9c-flow-m-86400-m3s-qualified',
#     'period': 86400,
#     'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#      'label': 'mean'},
#     'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#      'label': 'Qualified'}}},
#   {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/4ced4530-229b-4bca-8723-003040a6d40a',
#    'label': 'PENBERTH S.G',
#    'notation': '4ced4530-229b-4bca-8723-003040a6d40a',
#    'easting': 140014,
#    'northing': 22986,
#    'lat': 50.050073,
#    'long': -5.633119,
#    'type': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/def/core/Station'},
#     {'@id': 'http://environment.data.gov.uk/reference/def/core/SamplingLocation'}],
#    'riverName': 'Penberth River',
#    'stationReference': '48173',
#    'wiskiID': 'SW42F895',
#    'RLOIid': '3339',
#    'measures': {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/4ced4530-229b-4bca-8723-003040a6d40a-flow-m-86400-m3s-qualified',
#     'label': 'Qualified daily mean flow timeseries for SW42F895(PENBERTH S.G)',
#     'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#      'label': 'Water Flow'},
#     'unitName': 'm3/s',
#     'notation': '4ced4530-229b-4bca-8723-003040a6d40a-flow-m-86400-m3s-qualified',
#     'period': 86400,
#     'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#      'label': 'mean'},
#     'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#      'label': 'Qualified'}}},
#   {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/eb6c1930-b131-4d71-9ce2-3616abd6ea39',
#    'label': 'ST ERTH',
#    'notation': 'eb6c1930-b131-4d71-9ce2-3616abd6ea39',
#    'easting': 154881,
#    'northing': 34171,
#    'lat': 50.156796,
#    'long': -5.433024,
#    'type': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/def/core/Station'},
#     {'@id': 'http://environment.data.gov.uk/reference/def/core/SamplingLocation'}],
#    'riverName': 'River Hayle',
#    'stationReference': '48125',
#    'wiskiID': 'SW53F051',
#    'RLOIid': '3165',
#    'measures': [{'@id': 'http://environment.data.gov.uk/hydrology/id/measures/eb6c1930-b131-4d71-9ce2-3616abd6ea39-flow-m-86400-m3s-qualified',
#      'label': 'Qualified daily mean flow timeseries for SW53F051(ST ERTH)',
#      'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#       'label': 'Water Flow'},
#      'unitName': 'm3/s',
#      'notation': 'eb6c1930-b131-4d71-9ce2-3616abd6ea39-flow-m-86400-m3s-qualified',
#      'period': 86400,
#      'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#       'label': 'mean'},
#      'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#       'label': 'Qualified'}},
#     {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/eb6c1930-b131-4d71-9ce2-3616abd6ea39-flow--i-15_min-m3_s-measured',
#      'label': 'Measured flow 15 min timeseries for St Erth',
#      'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#       'label': 'Water Flow'},
#      'unitName': 'm3/s',
#      'notation': 'eb6c1930-b131-4d71-9ce2-3616abd6ea39-flow--i-15_min-m3_s-measured',
#      'period': 900,
#      'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#       'label': 'mean'},
#      'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Measured',
#       'label': 'Measured'}}]},
#   {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/88bdbcaa-28c4-44db-97f7-0a60d22a4e08',
#    'label': 'TRENEAR INTAKE',
#    'notation': '88bdbcaa-28c4-44db-97f7-0a60d22a4e08',
#    'easting': 167508,
#    'northing': 31043,
#    'lat': 50.133798,
#    'long': -5.254647,
#    'type': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/def/core/Station'},
#     {'@id': 'http://environment.data.gov.uk/reference/def/core/SamplingLocation'}],
#    'riverName': 'River Cober',
#    'stationReference': '48126',
#    'wiskiID': 'SW63F042',
#    'RLOIid': '3392',
#    'measures': [{'@id': 'http://environment.data.gov.uk/hydrology/id/measures/88bdbcaa-28c4-44db-97f7-0a60d22a4e08-flow--i-15_min-m3_s-measured',
#      'label': 'Measured flow 15 min timeseries for Trenear',
#      'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#       'label': 'Water Flow'},
#      'unitName': 'm3/s',
#      'notation': '88bdbcaa-28c4-44db-97f7-0a60d22a4e08-flow--i-15_min-m3_s-measured',
#      'period': 900,
#      'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#       'label': 'mean'},
#      'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Measured',
#       'label': 'Measured'}},
#     {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/88bdbcaa-28c4-44db-97f7-0a60d22a4e08-flow-m-86400-m3s-qualified',
#      'label': 'Qualified daily mean flow timeseries for SW63F042(TRENEAR INTAKE)',
#      'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#       'label': 'Water Flow'},
#      'unitName': 'm3/s',
#      'notation': '88bdbcaa-28c4-44db-97f7-0a60d22a4e08-flow-m-86400-m3s-qualified',
#      'period': 86400,
#      'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#       'label': 'mean'},
#      'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#       'label': 'Qualified'}}]},
#   {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/951f7162-24d4-45f4-a03e-ee55d3c864c1',
#    'label': 'PONSANOOTH',
#    'notation': '951f7162-24d4-45f4-a03e-ee55d3c864c1',
#    'easting': 176228,
#    'northing': 37642,
#    'lat': 50.196411,
#    'long': -5.136703,
#    'type': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/def/core/Station'},
#     {'@id': 'http://environment.data.gov.uk/reference/def/core/SamplingLocation'}],
#    'riverName': 'River Kennall',
#    'stationReference': '48183',
#    'wiskiID': 'SW73F053',
#    'RLOIid': '3385',
#    'measures': [{'@id': 'http://environment.data.gov.uk/hydrology/id/measures/951f7162-24d4-45f4-a03e-ee55d3c864c1-flow--i-15_min-m3_s-measured',
#      'label': 'Measured flow 15 min timeseries for Ponsanooth',
#      'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#       'label': 'Water Flow'},
#      'unitName': 'm3/s',
#      'notation': '951f7162-24d4-45f4-a03e-ee55d3c864c1-flow--i-15_min-m3_s-measured',
#      'period': 900,
#      'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#       'label': 'mean'},
#      'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Measured',
#       'label': 'Measured'}},
#     {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/951f7162-24d4-45f4-a03e-ee55d3c864c1-flow-m-86400-m3s-qualified',
#      'label': 'Qualified daily mean flow timeseries for SW73F053(PONSANOOTH)',
#      'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#       'label': 'Water Flow'},
#      'unitName': 'm3/s',
#      'notation': '951f7162-24d4-45f4-a03e-ee55d3c864c1-flow-m-86400-m3s-qualified',
#      'period': 86400,
#      'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#       'label': 'mean'},
#      'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#       'label': 'Qualified'}}]},
#   {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/6c7fdc2b-fb6a-44f4-a7f0-5ca1a1e38486',
#    'label': 'BISSOE',
#    'notation': '6c7fdc2b-fb6a-44f4-a7f0-5ca1a1e38486',
#    'easting': 177450,
#    'northing': 41277,
#    'lat': 50.229514,
#    'long': -5.12174,
#    'type': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/def/core/Station'},
#     {'@id': 'http://environment.data.gov.uk/reference/def/core/SamplingLocation'}],
#    'riverName': 'Carnon River',
#    'stationReference': '48137',
#    'wiskiID': 'SW74F056',
#    'RLOIid': '3161',
#    'measures': [{'@id': 'http://environment.data.gov.uk/hydrology/id/measures/6c7fdc2b-fb6a-44f4-a7f0-5ca1a1e38486-flow-m-86400-m3s-qualified',
#      'label': 'Qualified daily mean flow timeseries for SW74F056(BISSOE)',
#      'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#       'label': 'Water Flow'},
#      'unitName': 'm3/s',
#      'notation': '6c7fdc2b-fb6a-44f4-a7f0-5ca1a1e38486-flow-m-86400-m3s-qualified',
#      'period': 86400,
#      'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#       'label': 'mean'},
#      'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#       'label': 'Qualified'}},
#     {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/6c7fdc2b-fb6a-44f4-a7f0-5ca1a1e38486-flow--i-15_min-m3_s-measured',
#      'label': 'Measured flow 15 min timeseries for Carnon Bissoe',
#      'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#       'label': 'Water Flow'},
#      'unitName': 'm3/s',
#      'notation': '6c7fdc2b-fb6a-44f4-a7f0-5ca1a1e38486-flow--i-15_min-m3_s-measured',
#      'period': 900,
#      'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#       'label': 'mean'},
#      'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Measured',
#       'label': 'Measured'}}]},
#   {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/f516b38c-16cc-4cda-94e7-6a85ee01b7b3',
#    'label': 'TRURO',
#    'notation': 'f516b38c-16cc-4cda-94e7-6a85ee01b7b3',
#    'easting': 181975,
#    'northing': 45030,
#    'lat': 50.264905,
#    'long': -5.060551,
#    'type': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/def/core/Station'},
#     {'@id': 'http://environment.data.gov.uk/reference/def/core/SamplingLocation'}],
#    'riverName': 'River Kenwyn',
#    'stationReference': '48128',
#    'wiskiID': 'SW84F054',
#    'RLOIid': '3163',
#    'measures': [{'@id': 'http://environment.data.gov.uk/hydrology/id/measures/f516b38c-16cc-4cda-94e7-6a85ee01b7b3-flow-m-86400-m3s-qualified',
#      'label': 'Qualified daily mean flow timeseries for SW84F054(TRURO)',
#      'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#       'label': 'Water Flow'},
#      'unitName': 'm3/s',
#      'notation': 'f516b38c-16cc-4cda-94e7-6a85ee01b7b3-flow-m-86400-m3s-qualified',
#      'period': 86400,
#      'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#       'label': 'mean'},
#      'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#       'label': 'Qualified'}},
#     {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/f516b38c-16cc-4cda-94e7-6a85ee01b7b3-flow--i-15_min-m3_s-measured',
#      'label': 'Measured flow 15 min timeseries for Truro',
#      'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#       'label': 'Water Flow'},
#      'unitName': 'm3/s',
#      'notation': 'f516b38c-16cc-4cda-94e7-6a85ee01b7b3-flow--i-15_min-m3_s-measured',
#      'period': 900,
#      'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#       'label': 'mean'},
#      'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Measured',
#       'label': 'Measured'}}]},
#   {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/6afb7ae1-8e82-402d-ac57-d5f658c6d114',
#    'label': 'GWILLS',
#    'notation': '6afb7ae1-8e82-402d-ac57-d5f658c6d114',
#    'easting': 182866,
#    'northing': 59268,
#    'lat': 50.393097,
#    'long': -5.056267,
#    'type': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/def/core/Station'},
#     {'@id': 'http://environment.data.gov.uk/reference/def/core/SamplingLocation'}],
#    'riverName': 'River Gannel',
#    'stationReference': '49130',
#    'wiskiID': 'SW85F055',
#    'RLOIid': '3135',
#    'measures': [{'@id': 'http://environment.data.gov.uk/hydrology/id/measures/6afb7ae1-8e82-402d-ac57-d5f658c6d114-flow--i-15_min-m3_s-measured',
#      'label': 'Measured flow 15 min timeseries for Gwills',
#      'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#       'label': 'Water Flow'},
#      'unitName': 'm3/s',
#      'notation': '6afb7ae1-8e82-402d-ac57-d5f658c6d114-flow--i-15_min-m3_s-measured',
#      'period': 900,
#      'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#       'label': 'mean'},
#      'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Measured',
#       'label': 'Measured'}},
#     {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/6afb7ae1-8e82-402d-ac57-d5f658c6d114-flow-m-86400-m3s-qualified',
#      'label': 'Qualified daily mean flow timeseries for SW85F055(GWILLS)',
#      'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#       'label': 'Water Flow'},
#      'unitName': 'm3/s',
#      'notation': '6afb7ae1-8e82-402d-ac57-d5f658c6d114-flow-m-86400-m3s-qualified',
#      'period': 86400,
#      'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#       'label': 'mean'},
#      'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#       'label': 'Qualified'}}]},
#   {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/065d2a2a-113d-422e-ae2c-d3c24e48c47b',
#    'label': 'TREGONY',
#    'notation': '065d2a2a-113d-422e-ae2c-d3c24e48c47b',
#    'easting': 192107,
#    'northing': 44747,
#    'lat': 50.266018,
#    'long': -4.91843,
#    'type': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/def/core/Station'},
#     {'@id': 'http://environment.data.gov.uk/reference/def/core/SamplingLocation'}],
#    'riverName': 'River Fal',
#    'stationReference': '48108',
#    'wiskiID': 'SW94F056',
#    'RLOIid': '3174',
#    'measures': {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/065d2a2a-113d-422e-ae2c-d3c24e48c47b-flow-m-86400-m3s-qualified',
#     'label': 'Qualified daily mean flow timeseries for SW94F056(TREGONY)',
#     'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#      'label': 'Water Flow'},
#     'unitName': 'm3/s',
#     'notation': '065d2a2a-113d-422e-ae2c-d3c24e48c47b-flow-m-86400-m3s-qualified',
#     'period': 86400,
#     'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#      'label': 'mean'},
#     'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#      'label': 'Qualified'}}},
#   {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/a987b813-6ebb-44f8-bf5c-658a6a3762a5',
#    'label': 'DENBY',
#    'notation': 'a987b813-6ebb-44f8-bf5c-658a6a3762a5',
#    'easting': 201748,
#    'northing': 68159,
#    'lat': 50.479633,
#    'long': -4.795666,
#    'type': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/def/core/Station'},
#     {'@id': 'http://environment.data.gov.uk/reference/def/core/SamplingLocation'}],
#    'riverName': 'River Camel',
#    'stationReference': '49109',
#    'wiskiID': 'SX06F058',
#    'RLOIid': '3153',
#    'measures': [{'@id': 'http://environment.data.gov.uk/hydrology/id/measures/a987b813-6ebb-44f8-bf5c-658a6a3762a5-flow--i-15_min-m3_s-measured',
#      'label': 'Measured flow 15 min timeseries for DENBY',
#      'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#       'label': 'Water Flow'},
#      'unitName': 'm3/s',
#      'notation': 'a987b813-6ebb-44f8-bf5c-658a6a3762a5-flow--i-15_min-m3_s-measured',
#      'period': 900,
#      'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#       'label': 'mean'},
#      'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Measured',
#       'label': 'Measured'}},
#     {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/a987b813-6ebb-44f8-bf5c-658a6a3762a5-flow-m-86400-m3s-qualified',
#      'label': 'Qualified daily mean flow timeseries for SX06F058(DENBY)',
#      'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#       'label': 'Water Flow'},
#      'unitName': 'm3/s',
#      'notation': 'a987b813-6ebb-44f8-bf5c-658a6a3762a5-flow-m-86400-m3s-qualified',
#      'period': 86400,
#      'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#       'label': 'mean'},
#      'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#       'label': 'Qualified'}}]},
#   {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/a91dfed0-9614-4cf3-ba5a-d1a17c8c7282',
#    'label': 'RESTORMEL',
#    'notation': 'a91dfed0-9614-4cf3-ba5a-d1a17c8c7282',
#    'easting': 209796,
#    'northing': 62454,
#    'lat': 50.431052,
#    'long': -4.679467,
#    'type': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/def/core/Station'},
#     {'@id': 'http://environment.data.gov.uk/reference/def/core/SamplingLocation'}],
#    'riverName': 'River Fowey',
#    'stationReference': '49110',
#    'wiskiID': 'SX06F059',
#    'RLOIid': '3152',
#    'measures': [{'@id': 'http://environment.data.gov.uk/hydrology/id/measures/a91dfed0-9614-4cf3-ba5a-d1a17c8c7282-flow-m-86400-m3s-qualified',
#      'label': 'Qualified daily mean flow timeseries for SX06F059(RESTORMEL)',
#      'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#       'label': 'Water Flow'},
#      'unitName': 'm3/s',
#      'notation': 'a91dfed0-9614-4cf3-ba5a-d1a17c8c7282-flow-m-86400-m3s-qualified',
#      'period': 86400,
#      'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#       'label': 'mean'},
#      'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#       'label': 'Qualified'}},
#     {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/a91dfed0-9614-4cf3-ba5a-d1a17c8c7282-flow--i-15_min-m3_s-measured',
#      'label': 'Measured flow 15 min timeseries for Restormel',
#      'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#       'label': 'Water Flow'},
#      'unitName': 'm3/s',
#      'notation': 'a91dfed0-9614-4cf3-ba5a-d1a17c8c7282-flow--i-15_min-m3_s-measured',
#      'period': 900,
#      'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#       'label': 'mean'},
#      'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Measured',
#       'label': 'Measured'}}]},
#   {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/f87436ec-9077-49de-85c0-bf935ee0e3f8',
#    'label': 'TRENGOFFE',
#    'notation': 'f87436ec-9077-49de-85c0-bf935ee0e3f8',
#    'easting': 215951,
#    'northing': 67373,
#    'lat': 50.477206,
#    'long': -4.595318,
#    'type': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/def/core/Station'},
#     {'@id': 'http://environment.data.gov.uk/reference/def/core/SamplingLocation'}],
#    'riverName': 'Warleggan River',
#    'stationReference': '49121',
#    'wiskiID': 'SX16F060',
#    'RLOIid': '3141',
#    'measures': [{'@id': 'http://environment.data.gov.uk/hydrology/id/measures/f87436ec-9077-49de-85c0-bf935ee0e3f8-flow--i-15_min-m3_s-measured',
#      'label': 'Measured flow 15 min timeseries for Trengoffe',
#      'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#       'label': 'Water Flow'},
#      'unitName': 'm3/s',
#      'notation': 'f87436ec-9077-49de-85c0-bf935ee0e3f8-flow--i-15_min-m3_s-measured',
#      'period': 900,
#      'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#       'label': 'mean'},
#      'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Measured',
#       'label': 'Measured'}},
#     {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/f87436ec-9077-49de-85c0-bf935ee0e3f8-flow-m-86400-m3s-qualified',
#      'label': 'Qualified daily mean flow timeseries for SX16F060(TRENGOFFE)',
#      'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#       'label': 'Water Flow'},
#      'unitName': 'm3/s',
#      'notation': 'f87436ec-9077-49de-85c0-bf935ee0e3f8-flow-m-86400-m3s-qualified',
#      'period': 86400,
#      'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#       'label': 'mean'},
#      'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#       'label': 'Qualified'}}]},
#   {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/b805b347-4665-4986-ba35-43d67542a5c0',
#    'label': 'CRAIGSHILL WOOD',
#    'notation': 'b805b347-4665-4986-ba35-43d67542a5c0',
#    'easting': 218436,
#    'northing': 65995,
#    'lat': 50.465601,
#    'long': -4.559663,
#    'type': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/def/core/Station'},
#     {'@id': 'http://environment.data.gov.uk/reference/def/core/SamplingLocation'}],
#    'riverName': 'St Neot River',
#    'stationReference': '49115',
#    'wiskiID': 'SX16F062',
#    'RLOIid': '3147',
#    'measures': [{'@id': 'http://environment.data.gov.uk/hydrology/id/measures/b805b347-4665-4986-ba35-43d67542a5c0-flow--i-15_min-m3_s-measured',
#      'label': 'Measured flow 15 min timeseries for Craigshill Wood',
#      'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#       'label': 'Water Flow'},
#      'unitName': 'm3/s',
#      'notation': 'b805b347-4665-4986-ba35-43d67542a5c0-flow--i-15_min-m3_s-measured',
#      'period': 900,
#      'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#       'label': 'mean'},
#      'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Measured',
#       'label': 'Measured'}},
#     {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/b805b347-4665-4986-ba35-43d67542a5c0-flow-m-86400-m3s-qualified',
#      'label': 'Qualified daily mean flow timeseries for SX16F062(CRAIGSHILL WOOD)',
#      'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#       'label': 'Water Flow'},
#      'unitName': 'm3/s',
#      'notation': 'b805b347-4665-4986-ba35-43d67542a5c0-flow-m-86400-m3s-qualified',
#      'period': 86400,
#      'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#       'label': 'mean'},
#      'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#       'label': 'Qualified'}}]},
#   {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/9cba8a99-f947-4661-8745-3cf4350dfda5',
#    'label': 'COLLIFORD WEIR',
#    'notation': '9cba8a99-f947-4661-8745-3cf4350dfda5',
#    'easting': 217955,
#    'northing': 70936,
#    'lat': 50.509842,
#    'long': -4.568841,
#    'type': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/def/core/Station'},
#     {'@id': 'http://environment.data.gov.uk/reference/def/core/SamplingLocation'}],
#    'riverName': 'St Neot River',
#    'stationReference': '49128',
#    'wiskiID': 'SX17F025',
#    'measures': [{'@id': 'http://environment.data.gov.uk/hydrology/id/measures/9cba8a99-f947-4661-8745-3cf4350dfda5-flow--i-15_min-m3_s-measured',
#      'label': 'Measured flow 15 min timeseries for Colliford',
#      'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#       'label': 'Water Flow'},
#      'unitName': 'm3/s',
#      'notation': '9cba8a99-f947-4661-8745-3cf4350dfda5-flow--i-15_min-m3_s-measured',
#      'period': 900,
#      'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#       'label': 'mean'},
#      'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Measured',
#       'label': 'Measured'}},
#     {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/9cba8a99-f947-4661-8745-3cf4350dfda5-flow-m-86400-m3s-qualified',
#      'label': 'Qualified daily mean flow timeseries for SX17F025(COLLIFORD WEIR)',
#      'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#       'label': 'Water Flow'},
#      'unitName': 'm3/s',
#      'notation': '9cba8a99-f947-4661-8745-3cf4350dfda5-flow-m-86400-m3s-qualified',
#      'period': 86400,
#      'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#       'label': 'mean'},
#      'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#       'label': 'Qualified'}}]},
#   {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/724ddcb2-fed1-4e25-b7b7-055348b41fc2',
#    'label': 'DE LANK',
#    'notation': '724ddcb2-fed1-4e25-b7b7-055348b41fc2',
#    'easting': 213262,
#    'northing': 76556,
#    'lat': 50.55885,
#    'long': -4.637771,
#    'type': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/def/core/Station'},
#     {'@id': 'http://environment.data.gov.uk/reference/def/core/SamplingLocation'}],
#    'riverName': 'De Lank River',
#    'stationReference': '49129',
#    'wiskiID': 'SX17F063',
#    'RLOIid': '3136',
# ...
#     'label': 'Qualified daily mean flow timeseries for 531370(MIDFORD)',
#     'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#      'label': 'Water Flow'},
#     'unitName': 'm3/s',
#     'notation': '531370-flow-m-86400-m3s-qualified',
#     'period': 86400,
#     'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#      'label': 'mean'},
#     'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#      'label': 'Qualified'}}},
#   {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/531450',
#    'label': 'COMPTON DANDO',
#    'notation': '531450',
#    'easting': 364803,
#    'northing': 164723,
#    'lat': 51.380453,
#    'long': -2.507113,
#    'type': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/def/core/Station'},
#     {'@id': 'http://environment.data.gov.uk/reference/def/core/SamplingLocation'}],
#    'riverName': 'River Chew',
#    'wiskiID': '531450',
#    'measures': {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/531450-flow-m-86400-m3s-qualified',
#     'label': 'Qualified daily mean flow timeseries for 531450(COMPTON DANDO)',
#     'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#      'label': 'Water Flow'},
#     'unitName': 'm3/s',
#     'notation': '531450-flow-m-86400-m3s-qualified',
#     'period': 86400,
#     'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#      'label': 'mean'},
#     'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#      'label': 'Qualified'}}},
#   {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/542349',
#    'label': 'BERKELEY NEW',
#    'notation': '542349',
#    'easting': 368249,
#    'northing': 198731,
#    'lat': 51.686426,
#    'long': -2.460679,
#    'type': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/def/core/Station'},
#     {'@id': 'http://environment.data.gov.uk/reference/def/core/SamplingLocation'}],
#    'riverName': 'Little Avon',
#    'wiskiID': '542349',
#    'measures': {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/542349-flow-m-86400-m3s-qualified',
#     'label': 'Qualified daily mean flow timeseries for 542349(BERKELEY NEW)',
#     'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#      'label': 'Water Flow'},
#     'unitName': 'm3/s',
#     'notation': '542349-flow-m-86400-m3s-qualified',
#     'period': 86400,
#     'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#      'label': 'mean'},
#     'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#      'label': 'Qualified'}}},
#   {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/FWBM01_FW',
#    'label': 'BEAMINSTER HAMS PLOT',
#    'notation': 'FWBM01_FW',
#    'easting': 348005,
#    'northing': 101110,
#    'lat': 50.807196,
#    'long': -2.739279,
#    'type': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/def/core/Station'},
#     {'@id': 'http://environment.data.gov.uk/reference/def/core/SamplingLocation'}],
#    'riverName': 'River Brit',
#    'wiskiID': 'FWBM01_FW',
#    'measures': {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/FWBM01_FW-flow-m-86400-m3s-qualified',
#     'label': 'Qualified daily mean flow timeseries for FWBM01_FW(BEAMINSTER HAMS PLOT)',
#     'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#      'label': 'Water Flow'},
#     'unitName': 'm3/s',
#     'notation': 'FWBM01_FW-flow-m-86400-m3s-qualified',
#     'period': 86400,
#     'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#      'label': 'mean'},
#     'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#      'label': 'Qualified'}}},
#   {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/FWMR01_FW',
#    'label': 'BRIDPORT MAGDALEN LANE',
#    'notation': 'FWMR01_FW',
#    'easting': 345994,
#    'northing': 92854,
#    'lat': 50.732776,
#    'long': -2.766602,
#    'type': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/def/core/Station'},
#     {'@id': 'http://environment.data.gov.uk/reference/def/core/SamplingLocation'}],
#    'riverName': 'River Simene',
#    'wiskiID': 'FWMR01_FW',
#    'measures': {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/FWMR01_FW-flow-m-86400-m3s-qualified',
#     'label': 'Qualified daily mean flow timeseries for FWMR01_FW(BRIDPORT MAGDALEN LANE)',
#     'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#      'label': 'Water Flow'},
#     'unitName': 'm3/s',
#     'notation': 'FWMR01_FW-flow-m-86400-m3s-qualified',
#     'period': 86400,
#     'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#      'label': 'mean'},
#     'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#      'label': 'Qualified'}}},
#   {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/SS93F030',
#    'label': 'BESSOM BRIDGE',
#    'notation': 'SS93F030',
#    'easting': 298038,
#    'northing': 132655,
#    'lat': 51.084118,
#    'long': -3.457074,
#    'type': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/def/core/Station'},
#     {'@id': 'http://environment.data.gov.uk/reference/def/core/SamplingLocation'}],
#    'riverName': 'Withiel Florey Stream',
#    'wiskiID': 'SS93F030',
#    'measures': {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/SS93F030-flow-m-86400-m3s-qualified',
#     'label': 'Qualified daily mean flow timeseries for SS93F030(BESSOM BRIDGE)',
#     'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#      'label': 'Water Flow'},
#     'unitName': 'm3/s',
#     'notation': 'SS93F030-flow-m-86400-m3s-qualified',
#     'period': 86400,
#     'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#      'label': 'mean'},
#     'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#      'label': 'Qualified'}}},
#   {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/SS92F057',
#    'label': 'UPTON (TRIB)',
#    'notation': 'SS92F057',
#    'easting': 298814,
#    'northing': 128951,
#    'lat': 51.050959,
#    'long': -3.444961,
#    'type': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/def/core/Station'},
#     {'@id': 'http://environment.data.gov.uk/reference/def/core/SamplingLocation'}],
#    'riverName': 'Trib (Haddeo)',
#    'wiskiID': 'SS92F057',
#    'measures': {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/SS92F057-flow-m-86400-m3s-qualified',
#     'label': 'Qualified daily mean flow timeseries for SS92F057(UPTON (TRIB))',
#     'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#      'label': 'Water Flow'},
#     'unitName': 'm3/s',
#     'notation': 'SS92F057-flow-m-86400-m3s-qualified',
#     'period': 86400,
#     'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#      'label': 'mean'},
#     'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#      'label': 'Qualified'}}},
#   {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/SS92F056',
#    'label': 'UPTON',
#    'notation': 'SS92F056',
#    'easting': 298816,
#    'northing': 128885,
#    'lat': 51.050366,
#    'long': -3.444914,
#    'type': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/def/core/Station'},
#     {'@id': 'http://environment.data.gov.uk/reference/def/core/SamplingLocation'}],
#    'riverName': 'River Haddeo',
#    'wiskiID': 'SS92F056',
#    'measures': {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/SS92F056-flow-m-86400-m3s-qualified',
#     'label': 'Qualified daily mean flow timeseries for SS92F056(UPTON)',
#     'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#      'label': 'Water Flow'},
#     'unitName': 'm3/s',
#     'notation': 'SS92F056-flow-m-86400-m3s-qualified',
#     'period': 86400,
#     'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#      'label': 'mean'},
#     'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#      'label': 'Qualified'}}},
#   {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/SS92F051',
#    'label': 'WIMBLEBALL FOOTBRIDGE',
#    'notation': 'SS92F051',
#    'easting': 296222,
#    'northing': 129501,
#    'lat': 51.05544,
#    'long': -3.482085,
#    'type': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/def/core/Station'},
#     {'@id': 'http://environment.data.gov.uk/reference/def/core/SamplingLocation'}],
#    'riverName': 'River Haddeo',
#    'wiskiID': 'SS92F051',
#    'measures': {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/SS92F051-flow-m-86400-m3s-qualified',
#     'label': 'Qualified daily mean flow timeseries for SS92F051(WIMBLEBALL FOOTBRIDGE)',
#     'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#      'label': 'Water Flow'},
#     'unitName': 'm3/s',
#     'notation': 'SS92F051-flow-m-86400-m3s-qualified',
#     'period': 86400,
#     'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#      'label': 'mean'},
#     'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#      'label': 'Qualified'}}},
#   {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/530176',
#    'label': 'BRADFORD ON AVON GS',
#    'notation': '530176',
#    'easting': 381522,
#    'northing': 160445,
#    'lat': 51.342781,
#    'long': -2.266665,
#    'type': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/def/core/Station'},
#     {'@id': 'http://environment.data.gov.uk/reference/def/core/SamplingLocation'}],
#    'riverName': 'River Avon',
#    'wiskiID': '530176',
#    'measures': {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/530176-flow-m-86400-m3s-qualified',
#     'label': 'Qualified daily mean flow timeseries for 530176(BRADFORD ON AVON GS)',
#     'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#      'label': 'Water Flow'},
#     'unitName': 'm3/s',
#     'notation': '530176-flow-m-86400-m3s-qualified',
#     'period': 86400,
#     'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#      'label': 'mean'},
#     'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#      'label': 'Qualified'}}},
#   {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/432610',
#    'label': 'EAST MILLS FLUME',
#    'notation': '432610',
#    'easting': 415764,
#    'northing': 114351,
#    'lat': 50.928396,
#    'long': -1.77706,
#    'type': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/def/core/Station'},
#     {'@id': 'http://environment.data.gov.uk/reference/def/core/SamplingLocation'}],
#    'riverName': 'Hampshire Avon',
#    'wiskiID': '432610',
#    'measures': {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/432610-flow-m-86400-m3s-qualified',
#     'label': 'Qualified daily mean flow timeseries for 432610(EAST MILLS FLUME)',
#     'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#      'label': 'Water Flow'},
#     'unitName': 'm3/s',
#     'notation': '432610-flow-m-86400-m3s-qualified',
#     'period': 86400,
#     'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#      'label': 'mean'},
#     'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#      'label': 'Qualified'}}},
#   {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/445509',
#    'label': 'LOUDSMILL FISHPASS',
#    'notation': '445509',
#    'easting': 370821,
#    'northing': 90353,
#    'lat': 50.712068,
#    'long': -2.414628,
#    'type': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/def/core/Station'},
#     {'@id': 'http://environment.data.gov.uk/reference/def/core/SamplingLocation'}],
#    'riverName': 'Dorset Frome',
#    'wiskiID': '445509',
#    'measures': {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/445509-flow-m-86400-m3s-qualified',
#     'label': 'Qualified daily mean flow timeseries for 445509(LOUDSMILL FISHPASS)',
#     'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#      'label': 'Water Flow'},
#     'unitName': 'm3/s',
#     'notation': '445509-flow-m-86400-m3s-qualified',
#     'period': 86400,
#     'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#      'label': 'mean'},
#     'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#      'label': 'Qualified'}}},
#   {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/445510',
#    'label': 'LOUDSMILL NOT INCLUDING FISHPASS',
#    'notation': '445510',
#    'easting': 370848,
#    'northing': 90331,
#    'lat': 50.711872,
#    'long': -2.414244,
#    'type': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/def/core/Station'},
#     {'@id': 'http://environment.data.gov.uk/reference/def/core/SamplingLocation'}],
#    'riverName': 'Dorset Frome',
#    'wiskiID': '445510',
#    'measures': {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/445510-flow-m-86400-m3s-qualified',
#     'label': 'Qualified daily mean flow timeseries for 445510(LOUDSMILL NOT INCLUDING FISHPASS)',
#     'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#      'label': 'Water Flow'},
#     'unitName': 'm3/s',
#     'notation': '445510-flow-m-86400-m3s-qualified',
#     'period': 86400,
#     'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#      'label': 'mean'},
#     'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#      'label': 'Qualified'}}},
#   {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/BRIGHR',
#    'label': 'BRIGHTLINGSEA RG (TELEM)',
#    'notation': 'BRIGHR',
#    'easting': 607159,
#    'northing': 217720,
#    'lat': 51.819684,
#    'long': 1.004365,
#    'type': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/def/core/Station'},
#     {'@id': 'http://environment.data.gov.uk/reference/def/core/SamplingLocation'}],
#    'wiskiID': 'BRIGHR',
#    'measures': {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/BRIGHR-flow-m-900-m3s-qualified',
#     'label': 'Qualified daily mean flow timeseries for BRIGHR(BRIGHTLINGSEA RG (TELEM))',
#     'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#      'label': 'Water Flow'},
#     'unitName': 'm3/s',
#     'notation': 'BRIGHR-flow-m-900-m3s-qualified',
#     'period': 900,
#     'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#      'label': 'mean'},
#     'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#      'label': 'Qualified'}}},
#   {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/90888236',
#    'label': 'DIDMARTON 1',
#    'notation': '90888236',
#    'easting': 382800,
#    'northing': 187400,
#    'lat': 51.585185,
#    'long': -2.249637,
#    'type': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/def/core/Station'},
#     {'@id': 'http://environment.data.gov.uk/reference/def/core/SamplingLocation'}],
#    'wiskiID': '90888236',
#    'measures': {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/90888236-flow-m-900-m3s-qualified',
#     'label': 'Qualified daily mean flow timeseries for 90888236(DIDMARTON 1)',
#     'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#      'label': 'Water Flow'},
#     'unitName': 'm3/s',
#     'notation': '90888236-flow-m-900-m3s-qualified',
#     'period': 900,
#     'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#      'label': 'mean'},
#     'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#      'label': 'Qualified'}}}]}

# %%
# View measures available from API
measures = requests.get('http://environment.data.gov.uk/hydrology/id/measures')
measures.status_code
# Out:
# 200

# %%
# View the items contained in measures, this is a list of dictionaries (one dictionary for each station)
measures.json().get('items')
# Out:
# [{'@id': 'http://environment.data.gov.uk/hydrology/id/measures/f9fcfbc0-af1b-46f6-bf20-6d8aedc1c72f-flow-m-86400-m3s-qualified',
#   'label': 'Qualified daily mean flow timeseries for SS50F007(GRIBBLEFORD BRIDGE)',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 86400,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#    'label': 'Qualified'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/f9fcfbc0-af1b-46f6-bf20-6d8aedc1c72f',
#    'label': 'GRIBBLEFORD BRIDGE',
#    'wiskiID': 'SS50F007',
#    'stationReference': '50121',
#    'RLOIid': '3121'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': 'f9fcfbc0-af1b-46f6-bf20-6d8aedc1c72f-flow-m-86400-m3s-qualified'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/736dd802-46b4-4864-ae7e-9c470d21ad46-flow-m-86400-m3s-qualified',
#   'label': 'Qualified daily mean flow timeseries for SS50F042(JACOBSTOWE)',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 86400,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#    'label': 'Qualified'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/736dd802-46b4-4864-ae7e-9c470d21ad46',
#    'label': 'JACOBSTOWE',
#    'wiskiID': 'SS50F042',
#    'stationReference': '50120',
#    'RLOIid': '3122'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': '736dd802-46b4-4864-ae7e-9c470d21ad46-flow-m-86400-m3s-qualified'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/d2d2a44c-25cb-4b0d-b4a5-4929e1d11975-flow-m-86400-m3s-qualified',
#   'label': 'Qualified daily mean flow timeseries for SS51F004(TORRINGTON)',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 86400,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#    'label': 'Qualified'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/d2d2a44c-25cb-4b0d-b4a5-4929e1d11975',
#    'label': 'TORRINGTON',
#    'wiskiID': 'SS51F004',
#    'stationReference': '50116',
#    'RLOIid': '3126'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': 'd2d2a44c-25cb-4b0d-b4a5-4929e1d11975-flow-m-86400-m3s-qualified'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/d2d2a44c-25cb-4b0d-b4a5-4929e1d11975-flow--i-15_min-m3_s-measured',
#   'label': 'Measured flow 15 min timeseries for Torrington',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 900,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Measured',
#    'label': 'Measured'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/d2d2a44c-25cb-4b0d-b4a5-4929e1d11975',
#    'label': 'TORRINGTON',
#    'wiskiID': 'SS51F004',
#    'stationReference': '50116',
#    'RLOIid': '3126'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': 'd2d2a44c-25cb-4b0d-b4a5-4929e1d11975-flow--i-15_min-m3_s-measured'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/b7db631d-9aa8-49c1-9a61-b2824d0b42c8-flow-m-86400-m3s-qualified',
#   'label': 'Qualified daily mean flow timeseries for SS60F015(TAW BRIDGE)',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 86400,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#    'label': 'Qualified'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/b7db631d-9aa8-49c1-9a61-b2824d0b42c8',
#    'label': 'TAW BRIDGE',
#    'wiskiID': 'SS60F015',
#    'stationReference': '50119',
#    'RLOIid': '3123'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': 'b7db631d-9aa8-49c1-9a61-b2824d0b42c8-flow-m-86400-m3s-qualified'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/fafd42b9-ed79-459c-98a6-83b7692eab78-flow-m-86400-m3s-qualified',
#   'label': 'Qualified daily mean flow timeseries for SS62F001(UMBERLEIGH)',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 86400,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#    'label': 'Qualified'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/fafd42b9-ed79-459c-98a6-83b7692eab78',
#    'label': 'UMBERLEIGH',
#    'wiskiID': 'SS62F001',
#    'stationReference': '50140',
#    'RLOIid': '3106'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': 'fafd42b9-ed79-459c-98a6-83b7692eab78-flow-m-86400-m3s-qualified'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/fafd42b9-ed79-459c-98a6-83b7692eab78-flow--i-15_min-m3_s-measured',
#   'label': 'Measured flow 15 min timeseries for Umberleigh',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 900,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Measured',
#    'label': 'Measured'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/fafd42b9-ed79-459c-98a6-83b7692eab78',
#    'label': 'UMBERLEIGH',
#    'wiskiID': 'SS62F001',
#    'stationReference': '50140',
#    'RLOIid': '3106'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': 'fafd42b9-ed79-459c-98a6-83b7692eab78-flow--i-15_min-m3_s-measured'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/c001fee0-4166-478c-ba13-f7a38b325012-flow-m-86400-m3s-qualified',
#   'label': 'Qualified daily mean flow timeseries for SS62F002(WOODLEIGH)',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 86400,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#    'label': 'Qualified'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/c001fee0-4166-478c-ba13-f7a38b325012',
#    'label': 'WOODLEIGH',
#    'wiskiID': 'SS62F002',
#    'stationReference': '50115',
#    'RLOIid': '3127'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': 'c001fee0-4166-478c-ba13-f7a38b325012-flow-m-86400-m3s-qualified'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/c001fee0-4166-478c-ba13-f7a38b325012-flow--i-15_min-m3_s-measured',
#   'label': 'Measured flow 15 min timeseries for Woodleigh',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 900,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Measured',
#    'label': 'Measured'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/c001fee0-4166-478c-ba13-f7a38b325012',
#    'label': 'WOODLEIGH',
#    'wiskiID': 'SS62F002',
#    'stationReference': '50115',
#    'RLOIid': '3127'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': 'c001fee0-4166-478c-ba13-f7a38b325012-flow--i-15_min-m3_s-measured'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/1c1c7743-d410-49e6-a57c-4bfa9097eac7-flow-m-86400-m3s-qualified',
#   'label': 'Qualified daily mean flow timeseries for SS63F015(LEEHAMFORD BRIDGE)',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 86400,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#    'label': 'Qualified'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/1c1c7743-d410-49e6-a57c-4bfa9097eac7',
#    'label': 'LEEHAMFORD BRIDGE',
#    'wiskiID': 'SS63F015',
#    'stationReference': '50130'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': '1c1c7743-d410-49e6-a57c-4bfa9097eac7-flow-m-86400-m3s-qualified'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/3c4d4f78-2d0e-474a-b884-65a9daca18fb-flow-m-86400-m3s-qualified',
#   'label': 'Qualified daily mean flow timeseries for SS90F011(THORVERTON)',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 86400,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#    'label': 'Qualified'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/3c4d4f78-2d0e-474a-b884-65a9daca18fb',
#    'label': 'THORVERTON',
#    'wiskiID': 'SS90F011',
#    'stationReference': '45118',
#    'RLOIid': '3260'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': '3c4d4f78-2d0e-474a-b884-65a9daca18fb-flow-m-86400-m3s-qualified'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/3c4d4f78-2d0e-474a-b884-65a9daca18fb-flow--i-15_min-m3_s-measured',
#   'label': 'Measured flow 15 min timeseries for Thorverton',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 900,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Measured',
#    'label': 'Measured'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/3c4d4f78-2d0e-474a-b884-65a9daca18fb',
#    'label': 'THORVERTON',
#    'wiskiID': 'SS90F011',
#    'stationReference': '45118',
#    'RLOIid': '3260'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': '3c4d4f78-2d0e-474a-b884-65a9daca18fb-flow--i-15_min-m3_s-measured'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/33b613be-70df-4574-893e-f54443627dc1-flow-m-86400-m3s-qualified',
#   'label': 'Qualified daily mean flow timeseries for SS91F008(STOODLEIGH)',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 86400,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#    'label': 'Qualified'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/33b613be-70df-4574-893e-f54443627dc1',
#    'label': 'STOODLEIGH',
#    'wiskiID': 'SS91F008',
#    'stationReference': '45120',
#    'RLOIid': '3258'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': '33b613be-70df-4574-893e-f54443627dc1-flow-m-86400-m3s-qualified'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/4b146acd-5118-4e14-b23a-13405168a010-flow-m-86400-m3s-qualified',
#   'label': 'Qualified daily mean flow timeseries for SS92F008(BRUSHFORD)',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 86400,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#    'label': 'Qualified'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/4b146acd-5118-4e14-b23a-13405168a010',
#    'label': 'BRUSHFORD',
#    'wiskiID': 'SS92F008',
#    'stationReference': '45121',
#    'RLOIid': '3257'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': '4b146acd-5118-4e14-b23a-13405168a010-flow-m-86400-m3s-qualified'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/4b146acd-5118-4e14-b23a-13405168a010-flow--i-15_min-m3_s-measured',
#   'label': 'Measured flow 15 min timeseries for BRUSHFORD',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 900,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Measured',
#    'label': 'Measured'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/4b146acd-5118-4e14-b23a-13405168a010',
#    'label': 'BRUSHFORD',
#    'wiskiID': 'SS92F008',
#    'stationReference': '45121',
#    'RLOIid': '3257'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': '4b146acd-5118-4e14-b23a-13405168a010-flow--i-15_min-m3_s-measured'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/34202203-d1dc-4812-843a-715467152795-flow-m-86400-m3s-qualified',
#   'label': 'Qualified daily mean flow timeseries for SS92F014(PIXTON)',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 86400,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#    'label': 'Qualified'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/34202203-d1dc-4812-843a-715467152795',
#    'label': 'PIXTON',
#    'wiskiID': 'SS92F014',
#    'stationReference': '45122',
#    'RLOIid': '3256'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': '34202203-d1dc-4812-843a-715467152795-flow-m-86400-m3s-qualified'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/cf5d2388-a6ea-4dab-9be1-6fef42fbc66a-flow-m-86400-m3s-qualified',
#   'label': 'Qualified daily mean flow timeseries for SS92F053(WIMBLEBALL COMPENSATION)',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 86400,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#    'label': 'Qualified'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/cf5d2388-a6ea-4dab-9be1-6fef42fbc66a',
#    'label': 'WIMBLEBALL COMPENSATION',
#    'wiskiID': 'SS92F053',
#    'stationReference': '45129'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': 'cf5d2388-a6ea-4dab-9be1-6fef42fbc66a-flow-m-86400-m3s-qualified'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/cf5d2388-a6ea-4dab-9be1-6fef42fbc66a-flow--i-15_min-m3_s-measured',
#   'label': 'Measured flow 15 min timeseries for Wimbleball',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 900,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Measured',
#    'label': 'Measured'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/cf5d2388-a6ea-4dab-9be1-6fef42fbc66a',
#    'label': 'WIMBLEBALL COMPENSATION',
#    'wiskiID': 'SS92F053',
#    'stationReference': '45129'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': 'cf5d2388-a6ea-4dab-9be1-6fef42fbc66a-flow--i-15_min-m3_s-measured'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/d2dcdeb9-5c08-471b-8d86-e0e1bc1d4c9c-flow-m-86400-m3s-qualified',
#   'label': 'Qualified daily mean flow timeseries for ST00F008(WOODMILL)',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 86400,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#    'label': 'Qualified'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/d2dcdeb9-5c08-471b-8d86-e0e1bc1d4c9c',
#    'label': 'WOODMILL',
#    'wiskiID': 'ST00F008',
#    'stationReference': '45119',
#    'RLOIid': '3259'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': 'd2dcdeb9-5c08-471b-8d86-e0e1bc1d4c9c-flow-m-86400-m3s-qualified'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/4ced4530-229b-4bca-8723-003040a6d40a-flow-m-86400-m3s-qualified',
#   'label': 'Qualified daily mean flow timeseries for SW42F895(PENBERTH S.G)',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 86400,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#    'label': 'Qualified'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/4ced4530-229b-4bca-8723-003040a6d40a',
#    'label': 'PENBERTH S.G',
#    'wiskiID': 'SW42F895',
#    'stationReference': '48173',
#    'RLOIid': '3339'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': '4ced4530-229b-4bca-8723-003040a6d40a-flow-m-86400-m3s-qualified'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/eb6c1930-b131-4d71-9ce2-3616abd6ea39-flow-m-86400-m3s-qualified',
#   'label': 'Qualified daily mean flow timeseries for SW53F051(ST ERTH)',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 86400,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#    'label': 'Qualified'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/eb6c1930-b131-4d71-9ce2-3616abd6ea39',
#    'label': 'ST ERTH',
#    'wiskiID': 'SW53F051',
#    'stationReference': '48125',
#    'RLOIid': '3165'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': 'eb6c1930-b131-4d71-9ce2-3616abd6ea39-flow-m-86400-m3s-qualified'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/eb6c1930-b131-4d71-9ce2-3616abd6ea39-flow--i-15_min-m3_s-measured',
#   'label': 'Measured flow 15 min timeseries for St Erth',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 900,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Measured',
#    'label': 'Measured'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/eb6c1930-b131-4d71-9ce2-3616abd6ea39',
#    'label': 'ST ERTH',
#    'wiskiID': 'SW53F051',
#    'stationReference': '48125',
#    'RLOIid': '3165'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': 'eb6c1930-b131-4d71-9ce2-3616abd6ea39-flow--i-15_min-m3_s-measured'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/88bdbcaa-28c4-44db-97f7-0a60d22a4e08-flow-m-86400-m3s-qualified',
#   'label': 'Qualified daily mean flow timeseries for SW63F042(TRENEAR INTAKE)',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 86400,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#    'label': 'Qualified'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/88bdbcaa-28c4-44db-97f7-0a60d22a4e08',
#    'label': 'TRENEAR INTAKE',
#    'wiskiID': 'SW63F042',
#    'stationReference': '48126',
#    'RLOIid': '3392'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': '88bdbcaa-28c4-44db-97f7-0a60d22a4e08-flow-m-86400-m3s-qualified'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/88bdbcaa-28c4-44db-97f7-0a60d22a4e08-flow--i-15_min-m3_s-measured',
#   'label': 'Measured flow 15 min timeseries for Trenear',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 900,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Measured',
#    'label': 'Measured'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/88bdbcaa-28c4-44db-97f7-0a60d22a4e08',
#    'label': 'TRENEAR INTAKE',
#    'wiskiID': 'SW63F042',
#    'stationReference': '48126',
#    'RLOIid': '3392'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': '88bdbcaa-28c4-44db-97f7-0a60d22a4e08-flow--i-15_min-m3_s-measured'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/951f7162-24d4-45f4-a03e-ee55d3c864c1-flow-m-86400-m3s-qualified',
#   'label': 'Qualified daily mean flow timeseries for SW73F053(PONSANOOTH)',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 86400,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#    'label': 'Qualified'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/951f7162-24d4-45f4-a03e-ee55d3c864c1',
#    'label': 'PONSANOOTH',
#    'wiskiID': 'SW73F053',
#    'stationReference': '48183',
#    'RLOIid': '3385'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': '951f7162-24d4-45f4-a03e-ee55d3c864c1-flow-m-86400-m3s-qualified'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/951f7162-24d4-45f4-a03e-ee55d3c864c1-flow--i-15_min-m3_s-measured',
#   'label': 'Measured flow 15 min timeseries for Ponsanooth',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 900,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Measured',
#    'label': 'Measured'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/951f7162-24d4-45f4-a03e-ee55d3c864c1',
#    'label': 'PONSANOOTH',
#    'wiskiID': 'SW73F053',
#    'stationReference': '48183',
#    'RLOIid': '3385'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': '951f7162-24d4-45f4-a03e-ee55d3c864c1-flow--i-15_min-m3_s-measured'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/6c7fdc2b-fb6a-44f4-a7f0-5ca1a1e38486-flow-m-86400-m3s-qualified',
#   'label': 'Qualified daily mean flow timeseries for SW74F056(BISSOE)',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 86400,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#    'label': 'Qualified'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/6c7fdc2b-fb6a-44f4-a7f0-5ca1a1e38486',
#    'label': 'BISSOE',
#    'wiskiID': 'SW74F056',
#    'stationReference': '48137',
#    'RLOIid': '3161'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': '6c7fdc2b-fb6a-44f4-a7f0-5ca1a1e38486-flow-m-86400-m3s-qualified'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/6c7fdc2b-fb6a-44f4-a7f0-5ca1a1e38486-flow--i-15_min-m3_s-measured',
#   'label': 'Measured flow 15 min timeseries for Carnon Bissoe',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 900,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Measured',
#    'label': 'Measured'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/6c7fdc2b-fb6a-44f4-a7f0-5ca1a1e38486',
#    'label': 'BISSOE',
#    'wiskiID': 'SW74F056',
#    'stationReference': '48137',
#    'RLOIid': '3161'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': '6c7fdc2b-fb6a-44f4-a7f0-5ca1a1e38486-flow--i-15_min-m3_s-measured'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/f516b38c-16cc-4cda-94e7-6a85ee01b7b3-flow-m-86400-m3s-qualified',
#   'label': 'Qualified daily mean flow timeseries for SW84F054(TRURO)',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 86400,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#    'label': 'Qualified'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/f516b38c-16cc-4cda-94e7-6a85ee01b7b3',
#    'label': 'TRURO',
#    'wiskiID': 'SW84F054',
#    'stationReference': '48128',
#    'RLOIid': '3163'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': 'f516b38c-16cc-4cda-94e7-6a85ee01b7b3-flow-m-86400-m3s-qualified'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/f516b38c-16cc-4cda-94e7-6a85ee01b7b3-flow--i-15_min-m3_s-measured',
#   'label': 'Measured flow 15 min timeseries for Truro',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 900,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Measured',
#    'label': 'Measured'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/f516b38c-16cc-4cda-94e7-6a85ee01b7b3',
#    'label': 'TRURO',
#    'wiskiID': 'SW84F054',
#    'stationReference': '48128',
#    'RLOIid': '3163'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': 'f516b38c-16cc-4cda-94e7-6a85ee01b7b3-flow--i-15_min-m3_s-measured'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/6afb7ae1-8e82-402d-ac57-d5f658c6d114-flow-m-86400-m3s-qualified',
#   'label': 'Qualified daily mean flow timeseries for SW85F055(GWILLS)',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 86400,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#    'label': 'Qualified'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/6afb7ae1-8e82-402d-ac57-d5f658c6d114',
#    'label': 'GWILLS',
#    'wiskiID': 'SW85F055',
#    'stationReference': '49130',
#    'RLOIid': '3135'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': '6afb7ae1-8e82-402d-ac57-d5f658c6d114-flow-m-86400-m3s-qualified'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/6afb7ae1-8e82-402d-ac57-d5f658c6d114-flow--i-15_min-m3_s-measured',
#   'label': 'Measured flow 15 min timeseries for Gwills',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 900,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Measured',
#    'label': 'Measured'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/6afb7ae1-8e82-402d-ac57-d5f658c6d114',
#    'label': 'GWILLS',
#    'wiskiID': 'SW85F055',
#    'stationReference': '49130',
#    'RLOIid': '3135'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': '6afb7ae1-8e82-402d-ac57-d5f658c6d114-flow--i-15_min-m3_s-measured'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/065d2a2a-113d-422e-ae2c-d3c24e48c47b-flow-m-86400-m3s-qualified',
#   'label': 'Qualified daily mean flow timeseries for SW94F056(TREGONY)',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 86400,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#    'label': 'Qualified'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/065d2a2a-113d-422e-ae2c-d3c24e48c47b',
#    'label': 'TREGONY',
#    'wiskiID': 'SW94F056',
#    'stationReference': '48108',
#    'RLOIid': '3174'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': '065d2a2a-113d-422e-ae2c-d3c24e48c47b-flow-m-86400-m3s-qualified'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/a987b813-6ebb-44f8-bf5c-658a6a3762a5-flow-m-86400-m3s-qualified',
#   'label': 'Qualified daily mean flow timeseries for SX06F058(DENBY)',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 86400,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#    'label': 'Qualified'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/a987b813-6ebb-44f8-bf5c-658a6a3762a5',
#    'label': 'DENBY',
#    'wiskiID': 'SX06F058',
#    'stationReference': '49109',
#    'RLOIid': '3153'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': 'a987b813-6ebb-44f8-bf5c-658a6a3762a5-flow-m-86400-m3s-qualified'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/a987b813-6ebb-44f8-bf5c-658a6a3762a5-flow--i-15_min-m3_s-measured',
#   'label': 'Measured flow 15 min timeseries for DENBY',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 900,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Measured',
#    'label': 'Measured'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/a987b813-6ebb-44f8-bf5c-658a6a3762a5',
#    'label': 'DENBY',
#    'wiskiID': 'SX06F058',
#    'stationReference': '49109',
#    'RLOIid': '3153'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': 'a987b813-6ebb-44f8-bf5c-658a6a3762a5-flow--i-15_min-m3_s-measured'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/a91dfed0-9614-4cf3-ba5a-d1a17c8c7282-flow-m-86400-m3s-qualified',
#   'label': 'Qualified daily mean flow timeseries for SX06F059(RESTORMEL)',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 86400,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#    'label': 'Qualified'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/a91dfed0-9614-4cf3-ba5a-d1a17c8c7282',
#    'label': 'RESTORMEL',
#    'wiskiID': 'SX06F059',
#    'stationReference': '49110',
#    'RLOIid': '3152'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': 'a91dfed0-9614-4cf3-ba5a-d1a17c8c7282-flow-m-86400-m3s-qualified'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/a91dfed0-9614-4cf3-ba5a-d1a17c8c7282-flow--i-15_min-m3_s-measured',
#   'label': 'Measured flow 15 min timeseries for Restormel',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 900,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Measured',
#    'label': 'Measured'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/a91dfed0-9614-4cf3-ba5a-d1a17c8c7282',
#    'label': 'RESTORMEL',
#    'wiskiID': 'SX06F059',
#    'stationReference': '49110',
#    'RLOIid': '3152'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': 'a91dfed0-9614-4cf3-ba5a-d1a17c8c7282-flow--i-15_min-m3_s-measured'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/f87436ec-9077-49de-85c0-bf935ee0e3f8-flow-m-86400-m3s-qualified',
#   'label': 'Qualified daily mean flow timeseries for SX16F060(TRENGOFFE)',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 86400,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#    'label': 'Qualified'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/f87436ec-9077-49de-85c0-bf935ee0e3f8',
#    'label': 'TRENGOFFE',
#    'wiskiID': 'SX16F060',
#    'stationReference': '49121',
#    'RLOIid': '3141'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': 'f87436ec-9077-49de-85c0-bf935ee0e3f8-flow-m-86400-m3s-qualified'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/f87436ec-9077-49de-85c0-bf935ee0e3f8-flow--i-15_min-m3_s-measured',
#   'label': 'Measured flow 15 min timeseries for Trengoffe',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 900,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Measured',
#    'label': 'Measured'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/f87436ec-9077-49de-85c0-bf935ee0e3f8',
#    'label': 'TRENGOFFE',
#    'wiskiID': 'SX16F060',
#    'stationReference': '49121',
#    'RLOIid': '3141'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': 'f87436ec-9077-49de-85c0-bf935ee0e3f8-flow--i-15_min-m3_s-measured'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/b805b347-4665-4986-ba35-43d67542a5c0-flow-m-86400-m3s-qualified',
#   'label': 'Qualified daily mean flow timeseries for SX16F062(CRAIGSHILL WOOD)',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 86400,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#    'label': 'Qualified'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/b805b347-4665-4986-ba35-43d67542a5c0',
#    'label': 'CRAIGSHILL WOOD',
#    'wiskiID': 'SX16F062',
#    'stationReference': '49115',
#    'RLOIid': '3147'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': 'b805b347-4665-4986-ba35-43d67542a5c0-flow-m-86400-m3s-qualified'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/b805b347-4665-4986-ba35-43d67542a5c0-flow--i-15_min-m3_s-measured',
#   'label': 'Measured flow 15 min timeseries for Craigshill Wood',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 900,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Measured',
#    'label': 'Measured'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/b805b347-4665-4986-ba35-43d67542a5c0',
#    'label': 'CRAIGSHILL WOOD',
#    'wiskiID': 'SX16F062',
#    'stationReference': '49115',
#    'RLOIid': '3147'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': 'b805b347-4665-4986-ba35-43d67542a5c0-flow--i-15_min-m3_s-measured'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/9cba8a99-f947-4661-8745-3cf4350dfda5-flow-m-86400-m3s-qualified',
#   'label': 'Qualified daily mean flow timeseries for SX17F025(COLLIFORD WEIR)',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 86400,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#    'label': 'Qualified'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/9cba8a99-f947-4661-8745-3cf4350dfda5',
#    'label': 'COLLIFORD WEIR',
#    'wiskiID': 'SX17F025',
#    'stationReference': '49128'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': '9cba8a99-f947-4661-8745-3cf4350dfda5-flow-m-86400-m3s-qualified'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/9cba8a99-f947-4661-8745-3cf4350dfda5-flow--i-15_min-m3_s-measured',
#   'label': 'Measured flow 15 min timeseries for Colliford',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 900,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Measured',
#    'label': 'Measured'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/9cba8a99-f947-4661-8745-3cf4350dfda5',
#    'label': 'COLLIFORD WEIR',
#    'wiskiID': 'SX17F025',
#    'stationReference': '49128'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': '9cba8a99-f947-4661-8745-3cf4350dfda5-flow--i-15_min-m3_s-measured'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/724ddcb2-fed1-4e25-b7b7-055348b41fc2-flow-m-86400-m3s-qualified',
#   'label': 'Qualified daily mean flow timeseries for SX17F063(DE LANK)',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 86400,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#    'label': 'Qualified'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/724ddcb2-fed1-4e25-b7b7-055348b41fc2',
#    'label': 'DE LANK',
#    'wiskiID': 'SX17F063',
#    'stationReference': '49129',
#    'RLOIid': '3136'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': '724ddcb2-fed1-4e25-b7b7-055348b41fc2-flow-m-86400-m3s-qualified'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/724ddcb2-fed1-4e25-b7b7-055348b41fc2-flow--i-15_min-m3_s-measured',
#   'label': 'Measured flow 15 min timeseries for De Lank',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 900,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Measured',
#    'label': 'Measured'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/724ddcb2-fed1-4e25-b7b7-055348b41fc2',
#    'label': 'DE LANK',
#    'wiskiID': 'SX17F063',
#    'stationReference': '49129',
#    'RLOIid': '3136'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': '724ddcb2-fed1-4e25-b7b7-055348b41fc2-flow--i-15_min-m3_s-measured'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/b6cc814c-4b13-4645-89ee-25e8e3d79dc0-flow-m-86400-m3s-qualified',
#   'label': 'Qualified daily mean flow timeseries for SX25F064(TREBROWNBRIDGE)',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 86400,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#    'label': 'Qualified'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/b6cc814c-4b13-4645-89ee-25e8e3d79dc0',
#    'label': 'TREBROWNBRIDGE',
#    'wiskiID': 'SX25F064',
#    'stationReference': '49132',
#    'RLOIid': '3133'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': 'b6cc814c-4b13-4645-89ee-25e8e3d79dc0-flow-m-86400-m3s-qualified'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/b6cc814c-4b13-4645-89ee-25e8e3d79dc0-flow--i-15_min-m3_s-measured',
#   'label': 'Measured flow 15 min timeseries for Trebrownbridge',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 900,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Measured',
#    'label': 'Measured'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/b6cc814c-4b13-4645-89ee-25e8e3d79dc0',
#    'label': 'TREBROWNBRIDGE',
#    'wiskiID': 'SX25F064',
#    'stationReference': '49132',
#    'RLOIid': '3133'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': 'b6cc814c-4b13-4645-89ee-25e8e3d79dc0-flow--i-15_min-m3_s-measured'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/66c65f28-4f68-4aa1-8216-4d78d4f99138-flow-m-86400-m3s-qualified',
#   'label': 'Qualified daily mean flow timeseries for SX26F065(TREKEIVESTEPS)',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 86400,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#    'label': 'Qualified'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
# ...
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': '33b613be-70df-4574-893e-f54443627dc1-flow--i-15_min-m3_s-measured'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/004d8c0d-b7cf-49ae-aee7-52e37cd11aed-flow--i-15_min-m3_s-measured',
#   'label': 'Measured flow 15 min timeseries for Loverley Farm',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 900,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Measured',
#    'label': 'Measured'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/004d8c0d-b7cf-49ae-aee7-52e37cd11aed',
#    'label': 'Loverley Farm',
#    'wiskiID': '433529',
#    'stationReference': '43218',
#    'RLOIid': '9007'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': '004d8c0d-b7cf-49ae-aee7-52e37cd11aed-flow--i-15_min-m3_s-measured'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/4485824a-191e-4504-b0e4-7fa2e2119fb6-flow--i-15_min-m3_s-measured',
#   'label': 'Measured flow 15 min timeseries for Sydling St Nicholas',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 900,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Measured',
#    'label': 'Measured'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/4485824a-191e-4504-b0e4-7fa2e2119fb6',
#    'label': 'Sydling St Nicholas',
#    'wiskiID': '445410',
#    'stationReference': '44216',
#    'RLOIid': '3273'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': '4485824a-191e-4504-b0e4-7fa2e2119fb6-flow--i-15_min-m3_s-measured'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/5f23ee39-cca5-4cf3-a793-a3098db4b071-flow--i-15_min-m3_s-measured',
#   'label': 'Measured flow 15 min timeseries for Broadwey',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 900,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Measured',
#    'label': 'Measured'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/5f23ee39-cca5-4cf3-a793-a3098db4b071',
#    'label': 'Broadwey',
#    'wiskiID': '446020',
#    'stationReference': '44109',
#    'RLOIid': '3291'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': '5f23ee39-cca5-4cf3-a793-a3098db4b071-flow--i-15_min-m3_s-measured'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/b9f6ea7e-8e51-4647-ad81-a418ef6063ab-flow--i-15_min-m3_s-measured',
#   'label': 'Measured flow 15 min timeseries for Fenny Bridges',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 900,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Measured',
#    'label': 'Measured'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/b9f6ea7e-8e51-4647-ad81-a418ef6063ab',
#    'label': 'FENNY BRIDGES',
#    'wiskiID': 'SY19F052',
#    'stationReference': '45210',
#    'RLOIid': '3239'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': 'b9f6ea7e-8e51-4647-ad81-a418ef6063ab-flow--i-15_min-m3_s-measured'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/de59cc50-5443-4a4e-a560-352a4e1d9df0-flow--i-15_min-m3_s-measured',
#   'label': 'Measured flow 15 min timeseries for South Newton',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 900,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Measured',
#    'label': 'Measured'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/de59cc50-5443-4a4e-a560-352a4e1d9df0',
#    'label': 'South Newton',
#    'wiskiID': '432330',
#    'stationReference': '43111',
#    'RLOIid': '3327'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': 'de59cc50-5443-4a4e-a560-352a4e1d9df0-flow--i-15_min-m3_s-measured'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/f9fcfbc0-af1b-46f6-bf20-6d8aedc1c72f-flow--i-15_min-m3_s-measured',
#   'label': 'Measured flow 15 min timeseries for Gribbleford',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 900,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Measured',
#    'label': 'Measured'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/f9fcfbc0-af1b-46f6-bf20-6d8aedc1c72f',
#    'label': 'GRIBBLEFORD BRIDGE',
#    'wiskiID': 'SS50F007',
#    'stationReference': '50121',
#    'RLOIid': '3121'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': 'f9fcfbc0-af1b-46f6-bf20-6d8aedc1c72f-flow--i-15_min-m3_s-measured'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/5ea01221-9252-4e29-b92c-9b452255b5be-flow--i-15_min-m3_s-measured',
#   'label': 'Measured flow 15 min timeseries for Baggs Mill',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 900,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Measured',
#    'label': 'Measured'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/5ea01221-9252-4e29-b92c-9b452255b5be',
#    'label': 'Baggs Mill',
#    'wiskiID': '444510'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': '5ea01221-9252-4e29-b92c-9b452255b5be-flow--i-15_min-m3_s-measured'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/SS93F030-flow-m-86400-m3s-qualified',
#   'label': 'Qualified daily mean flow timeseries for SS93F030(BESSOM BRIDGE)',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 86400,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#    'label': 'Qualified'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/SS93F030',
#    'label': 'BESSOM BRIDGE',
#    'wiskiID': 'SS93F030'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': 'SS93F030-flow-m-86400-m3s-qualified'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/SS92F057-flow-m-86400-m3s-qualified',
#   'label': 'Qualified daily mean flow timeseries for SS92F057(UPTON (TRIB))',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 86400,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#    'label': 'Qualified'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/SS92F057',
#    'label': 'UPTON (TRIB)',
#    'wiskiID': 'SS92F057'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': 'SS92F057-flow-m-86400-m3s-qualified'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/SS92F056-flow-m-86400-m3s-qualified',
#   'label': 'Qualified daily mean flow timeseries for SS92F056(UPTON)',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 86400,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#    'label': 'Qualified'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/SS92F056',
#    'label': 'UPTON',
#    'wiskiID': 'SS92F056'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': 'SS92F056-flow-m-86400-m3s-qualified'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/SS92F051-flow-m-86400-m3s-qualified',
#   'label': 'Qualified daily mean flow timeseries for SS92F051(WIMBLEBALL FOOTBRIDGE)',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 86400,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#    'label': 'Qualified'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/SS92F051',
#    'label': 'WIMBLEBALL FOOTBRIDGE',
#    'wiskiID': 'SS92F051'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': 'SS92F051-flow-m-86400-m3s-qualified'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/530176-flow-m-86400-m3s-qualified',
#   'label': 'Qualified daily mean flow timeseries for 530176(BRADFORD ON AVON GS)',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 86400,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#    'label': 'Qualified'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/530176',
#    'label': 'BRADFORD ON AVON GS',
#    'wiskiID': '530176'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': '530176-flow-m-86400-m3s-qualified'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/432610-flow-m-86400-m3s-qualified',
#   'label': 'Qualified daily mean flow timeseries for 432610(EAST MILLS FLUME)',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 86400,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#    'label': 'Qualified'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/432610',
#    'label': 'EAST MILLS FLUME',
#    'wiskiID': '432610'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': '432610-flow-m-86400-m3s-qualified'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/445509-flow-m-86400-m3s-qualified',
#   'label': 'Qualified daily mean flow timeseries for 445509(LOUDSMILL FISHPASS)',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 86400,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#    'label': 'Qualified'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/445509',
#    'label': 'LOUDSMILL FISHPASS',
#    'wiskiID': '445509'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': '445509-flow-m-86400-m3s-qualified'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/445510-flow-m-86400-m3s-qualified',
#   'label': 'Qualified daily mean flow timeseries for 445510(LOUDSMILL NOT INCLUDING FISHPASS)',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 86400,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#    'label': 'Qualified'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/445510',
#    'label': 'LOUDSMILL NOT INCLUDING FISHPASS',
#    'wiskiID': '445510'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': '445510-flow-m-86400-m3s-qualified'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/BRIGHR-flow-m-900-m3s-qualified',
#   'label': 'Qualified daily mean flow timeseries for BRIGHR(BRIGHTLINGSEA RG (TELEM))',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 900,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#    'label': 'Qualified'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/BRIGHR',
#    'label': 'BRIGHTLINGSEA RG (TELEM)',
#    'wiskiID': 'BRIGHR'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': 'BRIGHR-flow-m-900-m3s-qualified'},
#  {'@id': 'http://environment.data.gov.uk/hydrology/id/measures/90888236-flow-m-900-m3s-qualified',
#   'label': 'Qualified daily mean flow timeseries for 90888236(DIDMARTON 1)',
#   'parameter': 'flow',
#   'parameterName': 'Flow',
#   'period': 900,
#   'valueStatistic': {'@id': 'http://environment.data.gov.uk/reference/def/core/mean',
#    'label': 'mean'},
#   'observationType': {'@id': 'http://environment.data.gov.uk/reference/def/core/Qualified',
#    'label': 'Qualified'},
#   'observedProperty': {'@id': 'http://environment.data.gov.uk/reference/def/op/waterFlow',
#    'label': 'Water Flow'},
#   'station': {'@id': 'http://environment.data.gov.uk/hydrology/id/stations/90888236',
#    'label': 'DIDMARTON 1',
#    'wiskiID': '90888236'},
#   'unit': {'@id': 'http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond'},
#   'unitName': 'm3/s',
#   'notation': '90888236-flow-m-900-m3s-qualified'}]

# %%
# View the output from measures in human readable format
test = json.dumps(measures.json(), sort_keys=True, indent = 4)
print(test)
# Out:
# {
#     "items": [
#         {
#             "@id": "http://environment.data.gov.uk/hydrology/id/measures/f9fcfbc0-af1b-46f6-bf20-6d8aedc1c72f-flow-m-86400-m3s-qualified",
#             "label": "Qualified daily mean flow timeseries for SS50F007(GRIBBLEFORD BRIDGE)",
#             "notation": "f9fcfbc0-af1b-46f6-bf20-6d8aedc1c72f-flow-m-86400-m3s-qualified",
#             "observationType": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/Qualified",
#                 "label": "Qualified"
#             },
#             "observedProperty": {
#                 "@id": "http://environment.data.gov.uk/reference/def/op/waterFlow",
#                 "label": "Water Flow"
#             },
#             "parameter": "flow",
#             "parameterName": "Flow",
#             "period": 86400,
#             "station": {
#                 "@id": "http://environment.data.gov.uk/hydrology/id/stations/f9fcfbc0-af1b-46f6-bf20-6d8aedc1c72f",
#                 "RLOIid": "3121",
#                 "label": "GRIBBLEFORD BRIDGE",
#                 "stationReference": "50121",
#                 "wiskiID": "SS50F007"
#             },
#             "unit": {
#                 "@id": "http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond"
#             },
#             "unitName": "m3/s",
#             "valueStatistic": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/mean",
#                 "label": "mean"
#             }
#         },
#         {
#             "@id": "http://environment.data.gov.uk/hydrology/id/measures/736dd802-46b4-4864-ae7e-9c470d21ad46-flow-m-86400-m3s-qualified",
#             "label": "Qualified daily mean flow timeseries for SS50F042(JACOBSTOWE)",
#             "notation": "736dd802-46b4-4864-ae7e-9c470d21ad46-flow-m-86400-m3s-qualified",
#             "observationType": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/Qualified",
#                 "label": "Qualified"
#             },
#             "observedProperty": {
#                 "@id": "http://environment.data.gov.uk/reference/def/op/waterFlow",
#                 "label": "Water Flow"
#             },
#             "parameter": "flow",
#             "parameterName": "Flow",
#             "period": 86400,
#             "station": {
#                 "@id": "http://environment.data.gov.uk/hydrology/id/stations/736dd802-46b4-4864-ae7e-9c470d21ad46",
#                 "RLOIid": "3122",
#                 "label": "JACOBSTOWE",
#                 "stationReference": "50120",
#                 "wiskiID": "SS50F042"
#             },
#             "unit": {
#                 "@id": "http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond"
#             },
#             "unitName": "m3/s",
#             "valueStatistic": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/mean",
#                 "label": "mean"
#             }
#         },
#         {
#             "@id": "http://environment.data.gov.uk/hydrology/id/measures/d2d2a44c-25cb-4b0d-b4a5-4929e1d11975-flow-m-86400-m3s-qualified",
#             "label": "Qualified daily mean flow timeseries for SS51F004(TORRINGTON)",
#             "notation": "d2d2a44c-25cb-4b0d-b4a5-4929e1d11975-flow-m-86400-m3s-qualified",
#             "observationType": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/Qualified",
#                 "label": "Qualified"
#             },
#             "observedProperty": {
#                 "@id": "http://environment.data.gov.uk/reference/def/op/waterFlow",
#                 "label": "Water Flow"
#             },
#             "parameter": "flow",
#             "parameterName": "Flow",
#             "period": 86400,
#             "station": {
#                 "@id": "http://environment.data.gov.uk/hydrology/id/stations/d2d2a44c-25cb-4b0d-b4a5-4929e1d11975",
#                 "RLOIid": "3126",
#                 "label": "TORRINGTON",
#                 "stationReference": "50116",
#                 "wiskiID": "SS51F004"
#             },
#             "unit": {
#                 "@id": "http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond"
#             },
#             "unitName": "m3/s",
#             "valueStatistic": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/mean",
#                 "label": "mean"
#             }
#         },
#         {
#             "@id": "http://environment.data.gov.uk/hydrology/id/measures/d2d2a44c-25cb-4b0d-b4a5-4929e1d11975-flow--i-15_min-m3_s-measured",
#             "label": "Measured flow 15 min timeseries for Torrington",
#             "notation": "d2d2a44c-25cb-4b0d-b4a5-4929e1d11975-flow--i-15_min-m3_s-measured",
#             "observationType": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/Measured",
#                 "label": "Measured"
#             },
#             "observedProperty": {
#                 "@id": "http://environment.data.gov.uk/reference/def/op/waterFlow",
#                 "label": "Water Flow"
#             },
#             "parameter": "flow",
#             "parameterName": "Flow",
#             "period": 900,
#             "station": {
#                 "@id": "http://environment.data.gov.uk/hydrology/id/stations/d2d2a44c-25cb-4b0d-b4a5-4929e1d11975",
#                 "RLOIid": "3126",
#                 "label": "TORRINGTON",
#                 "stationReference": "50116",
#                 "wiskiID": "SS51F004"
#             },
#             "unit": {
#                 "@id": "http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond"
#             },
#             "unitName": "m3/s",
#             "valueStatistic": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/mean",
#                 "label": "mean"
#             }
#         },
#         {
#             "@id": "http://environment.data.gov.uk/hydrology/id/measures/b7db631d-9aa8-49c1-9a61-b2824d0b42c8-flow-m-86400-m3s-qualified",
#             "label": "Qualified daily mean flow timeseries for SS60F015(TAW BRIDGE)",
#             "notation": "b7db631d-9aa8-49c1-9a61-b2824d0b42c8-flow-m-86400-m3s-qualified",
#             "observationType": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/Qualified",
#                 "label": "Qualified"
#             },
#             "observedProperty": {
#                 "@id": "http://environment.data.gov.uk/reference/def/op/waterFlow",
#                 "label": "Water Flow"
#             },
#             "parameter": "flow",
#             "parameterName": "Flow",
#             "period": 86400,
#             "station": {
#                 "@id": "http://environment.data.gov.uk/hydrology/id/stations/b7db631d-9aa8-49c1-9a61-b2824d0b42c8",
#                 "RLOIid": "3123",
#                 "label": "TAW BRIDGE",
#                 "stationReference": "50119",
#                 "wiskiID": "SS60F015"
#             },
#             "unit": {
#                 "@id": "http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond"
#             },
#             "unitName": "m3/s",
#             "valueStatistic": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/mean",
#                 "label": "mean"
#             }
#         },
#         {
#             "@id": "http://environment.data.gov.uk/hydrology/id/measures/fafd42b9-ed79-459c-98a6-83b7692eab78-flow-m-86400-m3s-qualified",
#             "label": "Qualified daily mean flow timeseries for SS62F001(UMBERLEIGH)",
#             "notation": "fafd42b9-ed79-459c-98a6-83b7692eab78-flow-m-86400-m3s-qualified",
#             "observationType": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/Qualified",
#                 "label": "Qualified"
#             },
#             "observedProperty": {
#                 "@id": "http://environment.data.gov.uk/reference/def/op/waterFlow",
#                 "label": "Water Flow"
#             },
#             "parameter": "flow",
#             "parameterName": "Flow",
#             "period": 86400,
#             "station": {
#                 "@id": "http://environment.data.gov.uk/hydrology/id/stations/fafd42b9-ed79-459c-98a6-83b7692eab78",
#                 "RLOIid": "3106",
#                 "label": "UMBERLEIGH",
#                 "stationReference": "50140",
#                 "wiskiID": "SS62F001"
#             },
#             "unit": {
#                 "@id": "http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond"
#             },
#             "unitName": "m3/s",
#             "valueStatistic": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/mean",
#                 "label": "mean"
#             }
#         },
#         {
#             "@id": "http://environment.data.gov.uk/hydrology/id/measures/fafd42b9-ed79-459c-98a6-83b7692eab78-flow--i-15_min-m3_s-measured",
#             "label": "Measured flow 15 min timeseries for Umberleigh",
#             "notation": "fafd42b9-ed79-459c-98a6-83b7692eab78-flow--i-15_min-m3_s-measured",
#             "observationType": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/Measured",
#                 "label": "Measured"
#             },
#             "observedProperty": {
#                 "@id": "http://environment.data.gov.uk/reference/def/op/waterFlow",
#                 "label": "Water Flow"
#             },
#             "parameter": "flow",
#             "parameterName": "Flow",
#             "period": 900,
#             "station": {
#                 "@id": "http://environment.data.gov.uk/hydrology/id/stations/fafd42b9-ed79-459c-98a6-83b7692eab78",
#                 "RLOIid": "3106",
#                 "label": "UMBERLEIGH",
#                 "stationReference": "50140",
#                 "wiskiID": "SS62F001"
#             },
#             "unit": {
#                 "@id": "http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond"
#             },
#             "unitName": "m3/s",
#             "valueStatistic": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/mean",
#                 "label": "mean"
#             }
#         },
#         {
#             "@id": "http://environment.data.gov.uk/hydrology/id/measures/c001fee0-4166-478c-ba13-f7a38b325012-flow-m-86400-m3s-qualified",
#             "label": "Qualified daily mean flow timeseries for SS62F002(WOODLEIGH)",
#             "notation": "c001fee0-4166-478c-ba13-f7a38b325012-flow-m-86400-m3s-qualified",
#             "observationType": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/Qualified",
#                 "label": "Qualified"
#             },
#             "observedProperty": {
#                 "@id": "http://environment.data.gov.uk/reference/def/op/waterFlow",
#                 "label": "Water Flow"
#             },
#             "parameter": "flow",
#             "parameterName": "Flow",
#             "period": 86400,
#             "station": {
#                 "@id": "http://environment.data.gov.uk/hydrology/id/stations/c001fee0-4166-478c-ba13-f7a38b325012",
#                 "RLOIid": "3127",
#                 "label": "WOODLEIGH",
#                 "stationReference": "50115",
#                 "wiskiID": "SS62F002"
#             },
#             "unit": {
#                 "@id": "http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond"
#             },
#             "unitName": "m3/s",
#             "valueStatistic": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/mean",
#                 "label": "mean"
#             }
#         },
#         {
#             "@id": "http://environment.data.gov.uk/hydrology/id/measures/c001fee0-4166-478c-ba13-f7a38b325012-flow--i-15_min-m3_s-measured",
#             "label": "Measured flow 15 min timeseries for Woodleigh",
#             "notation": "c001fee0-4166-478c-ba13-f7a38b325012-flow--i-15_min-m3_s-measured",
#             "observationType": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/Measured",
#                 "label": "Measured"
#             },
#             "observedProperty": {
#                 "@id": "http://environment.data.gov.uk/reference/def/op/waterFlow",
#                 "label": "Water Flow"
#             },
#             "parameter": "flow",
#             "parameterName": "Flow",
#             "period": 900,
#             "station": {
#                 "@id": "http://environment.data.gov.uk/hydrology/id/stations/c001fee0-4166-478c-ba13-f7a38b325012",
#                 "RLOIid": "3127",
#                 "label": "WOODLEIGH",
#                 "stationReference": "50115",
#                 "wiskiID": "SS62F002"
#             },
#             "unit": {
#                 "@id": "http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond"
#             },
#             "unitName": "m3/s",
#             "valueStatistic": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/mean",
#                 "label": "mean"
#             }
#         },
#         {
#             "@id": "http://environment.data.gov.uk/hydrology/id/measures/1c1c7743-d410-49e6-a57c-4bfa9097eac7-flow-m-86400-m3s-qualified",
#             "label": "Qualified daily mean flow timeseries for SS63F015(LEEHAMFORD BRIDGE)",
#             "notation": "1c1c7743-d410-49e6-a57c-4bfa9097eac7-flow-m-86400-m3s-qualified",
#             "observationType": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/Qualified",
#                 "label": "Qualified"
#             },
#             "observedProperty": {
#                 "@id": "http://environment.data.gov.uk/reference/def/op/waterFlow",
#                 "label": "Water Flow"
#             },
#             "parameter": "flow",
#             "parameterName": "Flow",
#             "period": 86400,
#             "station": {
#                 "@id": "http://environment.data.gov.uk/hydrology/id/stations/1c1c7743-d410-49e6-a57c-4bfa9097eac7",
#                 "label": "LEEHAMFORD BRIDGE",
#                 "stationReference": "50130",
#                 "wiskiID": "SS63F015"
#             },
#             "unit": {
#                 "@id": "http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond"
#             },
#             "unitName": "m3/s",
#             "valueStatistic": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/mean",
#                 "label": "mean"
#             }
#         },
#         {
#             "@id": "http://environment.data.gov.uk/hydrology/id/measures/3c4d4f78-2d0e-474a-b884-65a9daca18fb-flow-m-86400-m3s-qualified",
#             "label": "Qualified daily mean flow timeseries for SS90F011(THORVERTON)",
#             "notation": "3c4d4f78-2d0e-474a-b884-65a9daca18fb-flow-m-86400-m3s-qualified",
#             "observationType": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/Qualified",
#                 "label": "Qualified"
#             },
#             "observedProperty": {
#                 "@id": "http://environment.data.gov.uk/reference/def/op/waterFlow",
#                 "label": "Water Flow"
#             },
#             "parameter": "flow",
#             "parameterName": "Flow",
#             "period": 86400,
#             "station": {
#                 "@id": "http://environment.data.gov.uk/hydrology/id/stations/3c4d4f78-2d0e-474a-b884-65a9daca18fb",
#                 "RLOIid": "3260",
#                 "label": "THORVERTON",
#                 "stationReference": "45118",
#                 "wiskiID": "SS90F011"
#             },
#             "unit": {
#                 "@id": "http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond"
#             },
#             "unitName": "m3/s",
#             "valueStatistic": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/mean",
#                 "label": "mean"
#             }
#         },
#         {
#             "@id": "http://environment.data.gov.uk/hydrology/id/measures/3c4d4f78-2d0e-474a-b884-65a9daca18fb-flow--i-15_min-m3_s-measured",
#             "label": "Measured flow 15 min timeseries for Thorverton",
#             "notation": "3c4d4f78-2d0e-474a-b884-65a9daca18fb-flow--i-15_min-m3_s-measured",
#             "observationType": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/Measured",
#                 "label": "Measured"
#             },
#             "observedProperty": {
#                 "@id": "http://environment.data.gov.uk/reference/def/op/waterFlow",
#                 "label": "Water Flow"
#             },
#             "parameter": "flow",
#             "parameterName": "Flow",
#             "period": 900,
#             "station": {
#                 "@id": "http://environment.data.gov.uk/hydrology/id/stations/3c4d4f78-2d0e-474a-b884-65a9daca18fb",
#                 "RLOIid": "3260",
#                 "label": "THORVERTON",
#                 "stationReference": "45118",
#                 "wiskiID": "SS90F011"
#             },
#             "unit": {
#                 "@id": "http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond"
#             },
#             "unitName": "m3/s",
#             "valueStatistic": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/mean",
#                 "label": "mean"
#             }
#         },
#         {
#             "@id": "http://environment.data.gov.uk/hydrology/id/measures/33b613be-70df-4574-893e-f54443627dc1-flow-m-86400-m3s-qualified",
#             "label": "Qualified daily mean flow timeseries for SS91F008(STOODLEIGH)",
#             "notation": "33b613be-70df-4574-893e-f54443627dc1-flow-m-86400-m3s-qualified",
#             "observationType": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/Qualified",
#                 "label": "Qualified"
#             },
#             "observedProperty": {
#                 "@id": "http://environment.data.gov.uk/reference/def/op/waterFlow",
#                 "label": "Water Flow"
#             },
#             "parameter": "flow",
#             "parameterName": "Flow",
#             "period": 86400,
#             "station": {
#                 "@id": "http://environment.data.gov.uk/hydrology/id/stations/33b613be-70df-4574-893e-f54443627dc1",
#                 "RLOIid": "3258",
#                 "label": "STOODLEIGH",
#                 "stationReference": "45120",
#                 "wiskiID": "SS91F008"
#             },
#             "unit": {
#                 "@id": "http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond"
#             },
#             "unitName": "m3/s",
#             "valueStatistic": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/mean",
#                 "label": "mean"
#             }
#         },
#         {
#             "@id": "http://environment.data.gov.uk/hydrology/id/measures/4b146acd-5118-4e14-b23a-13405168a010-flow-m-86400-m3s-qualified",
#             "label": "Qualified daily mean flow timeseries for SS92F008(BRUSHFORD)",
#             "notation": "4b146acd-5118-4e14-b23a-13405168a010-flow-m-86400-m3s-qualified",
#             "observationType": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/Qualified",
#                 "label": "Qualified"
#             },
#             "observedProperty": {
#                 "@id": "http://environment.data.gov.uk/reference/def/op/waterFlow",
#                 "label": "Water Flow"
#             },
#             "parameter": "flow",
#             "parameterName": "Flow",
#             "period": 86400,
#             "station": {
#                 "@id": "http://environment.data.gov.uk/hydrology/id/stations/4b146acd-5118-4e14-b23a-13405168a010",
#                 "RLOIid": "3257",
#                 "label": "BRUSHFORD",
#                 "stationReference": "45121",
#                 "wiskiID": "SS92F008"
#             },
#             "unit": {
#                 "@id": "http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond"
#             },
#             "unitName": "m3/s",
#             "valueStatistic": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/mean",
#                 "label": "mean"
#             }
#         },
#         {
#             "@id": "http://environment.data.gov.uk/hydrology/id/measures/4b146acd-5118-4e14-b23a-13405168a010-flow--i-15_min-m3_s-measured",
#             "label": "Measured flow 15 min timeseries for BRUSHFORD",
#             "notation": "4b146acd-5118-4e14-b23a-13405168a010-flow--i-15_min-m3_s-measured",
#             "observationType": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/Measured",
#                 "label": "Measured"
#             },
#             "observedProperty": {
#                 "@id": "http://environment.data.gov.uk/reference/def/op/waterFlow",
#                 "label": "Water Flow"
#             },
#             "parameter": "flow",
#             "parameterName": "Flow",
#             "period": 900,
#             "station": {
#                 "@id": "http://environment.data.gov.uk/hydrology/id/stations/4b146acd-5118-4e14-b23a-13405168a010",
#                 "RLOIid": "3257",
#                 "label": "BRUSHFORD",
#                 "stationReference": "45121",
#                 "wiskiID": "SS92F008"
#             },
#             "unit": {
#                 "@id": "http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond"
#             },
#             "unitName": "m3/s",
#             "valueStatistic": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/mean",
#                 "label": "mean"
#             }
#         },
#         {
#             "@id": "http://environment.data.gov.uk/hydrology/id/measures/34202203-d1dc-4812-843a-715467152795-flow-m-86400-m3s-qualified",
#             "label": "Qualified daily mean flow timeseries for SS92F014(PIXTON)",
#             "notation": "34202203-d1dc-4812-843a-715467152795-flow-m-86400-m3s-qualified",
#             "observationType": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/Qualified",
#                 "label": "Qualified"
#             },
#             "observedProperty": {
#                 "@id": "http://environment.data.gov.uk/reference/def/op/waterFlow",
#                 "label": "Water Flow"
#             },
#             "parameter": "flow",
#             "parameterName": "Flow",
#             "period": 86400,
#             "station": {
#                 "@id": "http://environment.data.gov.uk/hydrology/id/stations/34202203-d1dc-4812-843a-715467152795",
#                 "RLOIid": "3256",
#                 "label": "PIXTON",
#                 "stationReference": "45122",
#                 "wiskiID": "SS92F014"
#             },
#             "unit": {
#                 "@id": "http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond"
#             },
#             "unitName": "m3/s",
#             "valueStatistic": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/mean",
#                 "label": "mean"
#             }
#         },
#         {
#             "@id": "http://environment.data.gov.uk/hydrology/id/measures/cf5d2388-a6ea-4dab-9be1-6fef42fbc66a-flow-m-86400-m3s-qualified",
#             "label": "Qualified daily mean flow timeseries for SS92F053(WIMBLEBALL COMPENSATION)",
#             "notation": "cf5d2388-a6ea-4dab-9be1-6fef42fbc66a-flow-m-86400-m3s-qualified",
#             "observationType": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/Qualified",
#                 "label": "Qualified"
#             },
#             "observedProperty": {
#                 "@id": "http://environment.data.gov.uk/reference/def/op/waterFlow",
#                 "label": "Water Flow"
#             },
#             "parameter": "flow",
#             "parameterName": "Flow",
#             "period": 86400,
#             "station": {
#                 "@id": "http://environment.data.gov.uk/hydrology/id/stations/cf5d2388-a6ea-4dab-9be1-6fef42fbc66a",
#                 "label": "WIMBLEBALL COMPENSATION",
#                 "stationReference": "45129",
#                 "wiskiID": "SS92F053"
#             },
#             "unit": {
#                 "@id": "http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond"
#             },
#             "unitName": "m3/s",
#             "valueStatistic": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/mean",
#                 "label": "mean"
#             }
#         },
#         {
#             "@id": "http://environment.data.gov.uk/hydrology/id/measures/cf5d2388-a6ea-4dab-9be1-6fef42fbc66a-flow--i-15_min-m3_s-measured",
#             "label": "Measured flow 15 min timeseries for Wimbleball",
#             "notation": "cf5d2388-a6ea-4dab-9be1-6fef42fbc66a-flow--i-15_min-m3_s-measured",
#             "observationType": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/Measured",
#                 "label": "Measured"
#             },
#             "observedProperty": {
#                 "@id": "http://environment.data.gov.uk/reference/def/op/waterFlow",
#                 "label": "Water Flow"
#             },
#             "parameter": "flow",
#             "parameterName": "Flow",
#             "period": 900,
#             "station": {
#                 "@id": "http://environment.data.gov.uk/hydrology/id/stations/cf5d2388-a6ea-4dab-9be1-6fef42fbc66a",
#                 "label": "WIMBLEBALL COMPENSATION",
#                 "stationReference": "45129",
#                 "wiskiID": "SS92F053"
#             },
#             "unit": {
#                 "@id": "http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond"
#             },
#             "unitName": "m3/s",
#             "valueStatistic": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/mean",
#                 "label": "mean"
#             }
#         },
#         {
#             "@id": "http://environment.data.gov.uk/hydrology/id/measures/d2dcdeb9-5c08-471b-8d86-e0e1bc1d4c9c-flow-m-86400-m3s-qualified",
#             "label": "Qualified daily mean flow timeseries for ST00F008(WOODMILL)",
#             "notation": "d2dcdeb9-5c08-471b-8d86-e0e1bc1d4c9c-flow-m-86400-m3s-qualified",
#             "observationType": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/Qualified",
#                 "label": "Qualified"
#             },
#             "observedProperty": {
#                 "@id": "http://environment.data.gov.uk/reference/def/op/waterFlow",
#                 "label": "Water Flow"
#             },
#             "parameter": "flow",
#             "parameterName": "Flow",
#             "period": 86400,
#             "station": {
#                 "@id": "http://environment.data.gov.uk/hydrology/id/stations/d2dcdeb9-5c08-471b-8d86-e0e1bc1d4c9c",
#                 "RLOIid": "3259",
#                 "label": "WOODMILL",
#                 "stationReference": "45119",
#                 "wiskiID": "ST00F008"
#             },
#             "unit": {
#                 "@id": "http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond"
#             },
#             "unitName": "m3/s",
#             "valueStatistic": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/mean",
#                 "label": "mean"
#             }
#         },
#         {
#             "@id": "http://environment.data.gov.uk/hydrology/id/measures/4ced4530-229b-4bca-8723-003040a6d40a-flow-m-86400-m3s-qualified",
#             "label": "Qualified daily mean flow timeseries for SW42F895(PENBERTH S.G)",
#             "notation": "4ced4530-229b-4bca-8723-003040a6d40a-flow-m-86400-m3s-qualified",
#             "observationType": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/Qualified",
#                 "label": "Qualified"
#             },
#             "observedProperty": {
#                 "@id": "http://environment.data.gov.uk/reference/def/op/waterFlow",
#                 "label": "Water Flow"
#             },
#             "parameter": "flow",
#             "parameterName": "Flow",
#             "period": 86400,
#             "station": {
#                 "@id": "http://environment.data.gov.uk/hydrology/id/stations/4ced4530-229b-4bca-8723-003040a6d40a",
#                 "RLOIid": "3339",
#                 "label": "PENBERTH S.G",
#                 "stationReference": "48173",
#                 "wiskiID": "SW42F895"
#             },
#             "unit": {
#                 "@id": "http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond"
#             },
#             "unitName": "m3/s",
#             "valueStatistic": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/mean",
#                 "label": "mean"
#             }
#         },
#         {
#             "@id": "http://environment.data.gov.uk/hydrology/id/measures/eb6c1930-b131-4d71-9ce2-3616abd6ea39-flow-m-86400-m3s-qualified",
#             "label": "Qualified daily mean flow timeseries for SW53F051(ST ERTH)",
#             "notation": "eb6c1930-b131-4d71-9ce2-3616abd6ea39-flow-m-86400-m3s-qualified",
#             "observationType": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/Qualified",
#                 "label": "Qualified"
#             },
#             "observedProperty": {
#                 "@id": "http://environment.data.gov.uk/reference/def/op/waterFlow",
#                 "label": "Water Flow"
#             },
#             "parameter": "flow",
#             "parameterName": "Flow",
#             "period": 86400,
#             "station": {
#                 "@id": "http://environment.data.gov.uk/hydrology/id/stations/eb6c1930-b131-4d71-9ce2-3616abd6ea39",
#                 "RLOIid": "3165",
#                 "label": "ST ERTH",
#                 "stationReference": "48125",
#                 "wiskiID": "SW53F051"
#             },
#             "unit": {
#                 "@id": "http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond"
#             },
#             "unitName": "m3/s",
#             "valueStatistic": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/mean",
#                 "label": "mean"
#             }
#         },
#         {
#             "@id": "http://environment.data.gov.uk/hydrology/id/measures/eb6c1930-b131-4d71-9ce2-3616abd6ea39-flow--i-15_min-m3_s-measured",
#             "label": "Measured flow 15 min timeseries for St Erth",
#             "notation": "eb6c1930-b131-4d71-9ce2-3616abd6ea39-flow--i-15_min-m3_s-measured",
#             "observationType": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/Measured",
#                 "label": "Measured"
#             },
#             "observedProperty": {
#                 "@id": "http://environment.data.gov.uk/reference/def/op/waterFlow",
#                 "label": "Water Flow"
#             },
#             "parameter": "flow",
#             "parameterName": "Flow",
#             "period": 900,
#             "station": {
#                 "@id": "http://environment.data.gov.uk/hydrology/id/stations/eb6c1930-b131-4d71-9ce2-3616abd6ea39",
#                 "RLOIid": "3165",
#                 "label": "ST ERTH",
#                 "stationReference": "48125",
#                 "wiskiID": "SW53F051"
#             },
#             "unit": {
#                 "@id": "http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond"
#             },
#             "unitName": "m3/s",
#             "valueStatistic": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/mean",
#                 "label": "mean"
#             }
#         },
#         {
#             "@id": "http://environment.data.gov.uk/hydrology/id/measures/88bdbcaa-28c4-44db-97f7-0a60d22a4e08-flow-m-86400-m3s-qualified",
#             "label": "Qualified daily mean flow timeseries for SW63F042(TRENEAR INTAKE)",
#             "notation": "88bdbcaa-28c4-44db-97f7-0a60d22a4e08-flow-m-86400-m3s-qualified",
#             "observationType": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/Qualified",
#                 "label": "Qualified"
#             },
#             "observedProperty": {
#                 "@id": "http://environment.data.gov.uk/reference/def/op/waterFlow",
#                 "label": "Water Flow"
#             },
#             "parameter": "flow",
#             "parameterName": "Flow",
#             "period": 86400,
#             "station": {
#                 "@id": "http://environment.data.gov.uk/hydrology/id/stations/88bdbcaa-28c4-44db-97f7-0a60d22a4e08",
#                 "RLOIid": "3392",
#                 "label": "TRENEAR INTAKE",
#                 "stationReference": "48126",
#                 "wiskiID": "SW63F042"
#             },
#             "unit": {
#                 "@id": "http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond"
#             },
#             "unitName": "m3/s",
#             "valueStatistic": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/mean",
#                 "label": "mean"
#             }
#         },
#         {
#             "@id": "http://environment.data.gov.uk/hydrology/id/measures/88bdbcaa-28c4-44db-97f7-0a60d22a4e08-flow--i-15_min-m3_s-measured",
#             "label": "Measured flow 15 min timeseries for Trenear",
#             "notation": "88bdbcaa-28c4-44db-97f7-0a60d22a4e08-flow--i-15_min-m3_s-measured",
#             "observationType": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/Measured",
#                 "label": "Measured"
#             },
#             "observedProperty": {
#                 "@id": "http://environment.data.gov.uk/reference/def/op/waterFlow",
#                 "label": "Water Flow"
#             },
#             "parameter": "flow",
#             "parameterName": "Flow",
#             "period": 900,
#             "station": {
#                 "@id": "http://environment.data.gov.uk/hydrology/id/stations/88bdbcaa-28c4-44db-97f7-0a60d22a4e08",
#                 "RLOIid": "3392",
#                 "label": "TRENEAR INTAKE",
#                 "stationReference": "48126",
#                 "wiskiID": "SW63F042"
#             },
#             "unit": {
#                 "@id": "http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond"
#             },
#             "unitName": "m3/s",
#             "valueStatistic": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/mean",
#                 "label": "mean"
#             }
#         },
#         {
#             "@id": "http://environment.data.gov.uk/hydrology/id/measures/951f7162-24d4-45f4-a03e-ee55d3c864c1-flow-m-86400-m3s-qualified",
#             "label": "Qualified daily mean flow timeseries for SW73F053(PONSANOOTH)",
#             "notation": "951f7162-24d4-45f4-a03e-ee55d3c864c1-flow-m-86400-m3s-qualified",
#             "observationType": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/Qualified",
#                 "label": "Qualified"
#             },
#             "observedProperty": {
#                 "@id": "http://environment.data.gov.uk/reference/def/op/waterFlow",
#                 "label": "Water Flow"
#             },
#             "parameter": "flow",
#             "parameterName": "Flow",
#             "period": 86400,
#             "station": {
#                 "@id": "http://environment.data.gov.uk/hydrology/id/stations/951f7162-24d4-45f4-a03e-ee55d3c864c1",
#                 "RLOIid": "3385",
#                 "label": "PONSANOOTH",
#                 "stationReference": "48183",
#                 "wiskiID": "SW73F053"
#             },
#             "unit": {
#                 "@id": "http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond"
#             },
#             "unitName": "m3/s",
#             "valueStatistic": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/mean",
#                 "label": "mean"
#             }
#         },
#         {
#             "@id": "http://environment.data.gov.uk/hydrology/id/measures/951f7162-24d4-45f4-a03e-ee55d3c864c1-flow--i-15_min-m3_s-measured",
#             "label": "Measured flow 15 min timeseries for Ponsanooth",
#             "notation": "951f7162-24d4-45f4-a03e-ee55d3c864c1-flow--i-15_min-m3_s-measured",
#             "observationType": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/Measured",
#                 "label": "Measured"
#             },
#             "observedProperty": {
#                 "@id": "http://environment.data.gov.uk/reference/def/op/waterFlow",
#                 "label": "Water Flow"
#             },
#             "parameter": "flow",
#             "parameterName": "Flow",
#             "period": 900,
#             "station": {
#                 "@id": "http://environment.data.gov.uk/hydrology/id/stations/951f7162-24d4-45f4-a03e-ee55d3c864c1",
#                 "RLOIid": "3385",
#                 "label": "PONSANOOTH",
#                 "stationReference": "48183",
#                 "wiskiID": "SW73F053"
#             },
#             "unit": {
#                 "@id": "http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond"
#             },
#             "unitName": "m3/s",
#             "valueStatistic": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/mean",
#                 "label": "mean"
#             }
#         },
#         {
#             "@id": "http://environment.data.gov.uk/hydrology/id/measures/6c7fdc2b-fb6a-44f4-a7f0-5ca1a1e38486-flow-m-86400-m3s-qualified",
#             "label": "Qualified daily mean flow timeseries for SW74F056(BISSOE)",
#             "notation": "6c7fdc2b-fb6a-44f4-a7f0-5ca1a1e38486-flow-m-86400-m3s-qualified",
#             "observationType": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/Qualified",
#                 "label": "Qualified"
#             },
#             "observedProperty": {
#                 "@id": "http://environment.data.gov.uk/reference/def/op/waterFlow",
#                 "label": "Water Flow"
#             },
#             "parameter": "flow",
#             "parameterName": "Flow",
#             "period": 86400,
#             "station": {
#                 "@id": "http://environment.data.gov.uk/hydrology/id/stations/6c7fdc2b-fb6a-44f4-a7f0-5ca1a1e38486",
#                 "RLOIid": "3161",
#                 "label": "BISSOE",
#                 "stationReference": "48137",
#                 "wiskiID": "SW74F056"
#             },
#             "unit": {
#                 "@id": "http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond"
#             },
#             "unitName": "m3/s",
#             "valueStatistic": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/mean",
#                 "label": "mean"
#             }
#         },
#         {
#             "@id": "http://environment.data.gov.uk/hydrology/id/measures/6c7fdc2b-fb6a-44f4-a7f0-5ca1a1e38486-flow--i-15_min-m3_s-measured",
#             "label": "Measured flow 15 min timeseries for Carnon Bissoe",
#             "notation": "6c7fdc2b-fb6a-44f4-a7f0-5ca1a1e38486-flow--i-15_min-m3_s-measured",
#             "observationType": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/Measured",
#                 "label": "Measured"
#             },
#             "observedProperty": {
#                 "@id": "http://environment.data.gov.uk/reference/def/op/waterFlow",
#                 "label": "Water Flow"
#             },
#             "parameter": "flow",
#             "parameterName": "Flow",
#             "period": 900,
#             "station": {
#                 "@id": "http://environment.data.gov.uk/hydrology/id/stations/6c7fdc2b-fb6a-44f4-a7f0-5ca1a1e38486",
#                 "RLOIid": "3161",
#                 "label": "BISSOE",
#                 "stationReference": "48137",
#                 "wiskiID": "SW74F056"
#             },
#             "unit": {
#                 "@id": "http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond"
#             },
#             "unitName": "m3/s",
#             "valueStatistic": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/mean",
#                 "label": "mean"
#             }
#         },
#         {
#             "@id": "http://environment.data.gov.uk/hydrology/id/measures/f516b38c-16cc-4cda-94e7-6a85ee01b7b3-flow-m-86400-m3s-qualified",
#             "label": "Qualified daily mean flow timeseries for SW84F054(TRURO)",
#             "notation": "f516b38c-16cc-4cda-94e7-6a85ee01b7b3-flow-m-86400-m3s-qualified",
#             "observationType": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/Qualified",
#                 "label": "Qualified"
#             },
#             "observedProperty": {
#                 "@id": "http://environment.data.gov.uk/reference/def/op/waterFlow",
#                 "label": "Water Flow"
#             },
#             "parameter": "flow",
#             "parameterName": "Flow",
#             "period": 86400,
#             "station": {
#                 "@id": "http://environment.data.gov.uk/hydrology/id/stations/f516b38c-16cc-4cda-94e7-6a85ee01b7b3",
#                 "RLOIid": "3163",
#                 "label": "TRURO",
#                 "stationReference": "48128",
#                 "wiskiID": "SW84F054"
#             },
#             "unit": {
#                 "@id": "http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond"
#             },
#             "unitName": "m3/s",
#             "valueStatistic": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/mean",
#                 "label": "mean"
#             }
#         },
#         {
#             "@id": "http://environment.data.gov.uk/hydrology/id/measures/f516b38c-16cc-4cda-94e7-6a85ee01b7b3-flow--i-15_min-m3_s-measured",
#             "label": "Measured flow 15 min timeseries for Truro",
#             "notation": "f516b38c-16cc-4cda-94e7-6a85ee01b7b3-flow--i-15_min-m3_s-measured",
#             "observationType": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/Measured",
#                 "label": "Measured"
#             },
#             "observedProperty": {
#                 "@id": "http://environment.data.gov.uk/reference/def/op/waterFlow",
#                 "label": "Water Flow"
#             },
#             "parameter": "flow",
#             "parameterName": "Flow",
#             "period": 900,
#             "station": {
#                 "@id": "http://environment.data.gov.uk/hydrology/id/stations/f516b38c-16cc-4cda-94e7-6a85ee01b7b3",
#                 "RLOIid": "3163",
#                 "label": "TRURO",
#                 "stationReference": "48128",
#                 "wiskiID": "SW84F054"
#             },
#             "unit": {
#                 "@id": "http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond"
#             },
#             "unitName": "m3/s",
#             "valueStatistic": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/mean",
#                 "label": "mean"
#             }
#         },
#         {
#             "@id": "http://environment.data.gov.uk/hydrology/id/measures/6afb7ae1-8e82-402d-ac57-d5f658c6d114-flow-m-86400-m3s-qualified",
#             "label": "Qualified daily mean flow timeseries for SW85F055(GWILLS)",
#             "notation": "6afb7ae1-8e82-402d-ac57-d5f658c6d114-flow-m-86400-m3s-qualified",
#             "observationType": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/Qualified",
#                 "label": "Qualified"
#             },
#             "observedProperty": {
#                 "@id": "http://environment.data.gov.uk/reference/def/op/waterFlow",
#                 "label": "Water Flow"
#             },
#             "parameter": "flow",
#             "parameterName": "Flow",
#             "period": 86400,
#             "station": {
#                 "@id": "http://environment.data.gov.uk/hydrology/id/stations/6afb7ae1-8e82-402d-ac57-d5f658c6d114",
#                 "RLOIid": "3135",
#                 "label": "GWILLS",
#                 "stationReference": "49130",
#                 "wiskiID": "SW85F055"
#             },
#             "unit": {
#                 "@id": "http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond"
#             },
#             "unitName": "m3/s",
#             "valueStatistic": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/mean",
#                 "label": "mean"
#             }
#         },
#         {
#             "@id": "http://environment.data.gov.uk/hydrology/id/measures/6afb7ae1-8e82-402d-ac57-d5f658c6d114-flow--i-15_min-m3_s-measured",
#             "label": "Measured flow 15 min timeseries for Gwills",
#             "notation": "6afb7ae1-8e82-402d-ac57-d5f658c6d114-flow--i-15_min-m3_s-measured",
#             "observationType": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/Measured",
#                 "label": "Measured"
#             },
#             "observedProperty": {
#                 "@id": "http://environment.data.gov.uk/reference/def/op/waterFlow",
#                 "label": "Water Flow"
#             },
#             "parameter": "flow",
#             "parameterName": "Flow",
#             "period": 900,
#             "station": {
#                 "@id": "http://environment.data.gov.uk/hydrology/id/stations/6afb7ae1-8e82-402d-ac57-d5f658c6d114",
#                 "RLOIid": "3135",
#                 "label": "GWILLS",
#                 "stationReference": "49130",
#                 "wiskiID": "SW85F055"
#             },
#             "unit": {
#                 "@id": "http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond"
#             },
#             "unitName": "m3/s",
#             "valueStatistic": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/mean",
#                 "label": "mean"
#             }
#         },
#         {
#             "@id": "http://environment.data.gov.uk/hydrology/id/measures/065d2a2a-113d-422e-ae2c-d3c24e48c47b-flow-m-86400-m3s-qualified",
#             "label": "Qualified daily mean flow timeseries for SW94F056(TREGONY)",
#             "notation": "065d2a2a-113d-422e-ae2c-d3c24e48c47b-flow-m-86400-m3s-qualified",
#             "observationType": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/Qualified",
#                 "label": "Qualified"
#             },
#             "observedProperty": {
#                 "@id": "http://environment.data.gov.uk/reference/def/op/waterFlow",
#                 "label": "Water Flow"
#             },
#             "parameter": "flow",
#             "parameterName": "Flow",
#             "period": 86400,
#             "station": {
#                 "@id": "http://environment.data.gov.uk/hydrology/id/stations/065d2a2a-113d-422e-ae2c-d3c24e48c47b",
#                 "RLOIid": "3174",
#                 "label": "TREGONY",
#                 "stationReference": "48108",
#                 "wiskiID": "SW94F056"
#             },
#             "unit": {
#                 "@id": "http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond"
#             },
#             "unitName": "m3/s",
#             "valueStatistic": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/mean",
#                 "label": "mean"
#             }
#         },
#         {
#             "@id": "http://environment.data.gov.uk/hydrology/id/measures/a987b813-6ebb-44f8-bf5c-658a6a3762a5-flow-m-86400-m3s-qualified",
#             "label": "Qualified daily mean flow timeseries for SX06F058(DENBY)",
#             "notation": "a987b813-6ebb-44f8-bf5c-658a6a3762a5-flow-m-86400-m3s-qualified",
#             "observationType": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/Qualified",
#                 "label": "Qualified"
#             },
#             "observedProperty": {
#                 "@id": "http://environment.data.gov.uk/reference/def/op/waterFlow",
#                 "label": "Water Flow"
#             },
#             "parameter": "flow",
#             "parameterName": "Flow",
#             "period": 86400,
#             "station": {
#                 "@id": "http://environment.data.gov.uk/hydrology/id/stations/a987b813-6ebb-44f8-bf5c-658a6a3762a5",
#                 "RLOIid": "3153",
#                 "label": "DENBY",
#                 "stationReference": "49109",
#                 "wiskiID": "SX06F058"
#             },
#             "unit": {
#                 "@id": "http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond"
#             },
#             "unitName": "m3/s",
#             "valueStatistic": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/mean",
#                 "label": "mean"
#             }
#         },
#         {
#             "@id": "http://environment.data.gov.uk/hydrology/id/measures/a987b813-6ebb-44f8-bf5c-658a6a3762a5-flow--i-15_min-m3_s-measured",
#             "label": "Measured flow 15 min timeseries for DENBY",
#             "notation": "a987b813-6ebb-44f8-bf5c-658a6a3762a5-flow--i-15_min-m3_s-measured",
#             "observationType": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/Measured",
#                 "label": "Measured"
#             },
#             "observedProperty": {
#                 "@id": "http://environment.data.gov.uk/reference/def/op/waterFlow",
#                 "label": "Water Flow"
#             },
#             "parameter": "flow",
#             "parameterName": "Flow",
#             "period": 900,
#             "station": {
# ...
#             "valueStatistic": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/mean",
#                 "label": "mean"
#             }
#         },
#         {
#             "@id": "http://environment.data.gov.uk/hydrology/id/measures/f9fcfbc0-af1b-46f6-bf20-6d8aedc1c72f-flow--i-15_min-m3_s-measured",
#             "label": "Measured flow 15 min timeseries for Gribbleford",
#             "notation": "f9fcfbc0-af1b-46f6-bf20-6d8aedc1c72f-flow--i-15_min-m3_s-measured",
#             "observationType": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/Measured",
#                 "label": "Measured"
#             },
#             "observedProperty": {
#                 "@id": "http://environment.data.gov.uk/reference/def/op/waterFlow",
#                 "label": "Water Flow"
#             },
#             "parameter": "flow",
#             "parameterName": "Flow",
#             "period": 900,
#             "station": {
#                 "@id": "http://environment.data.gov.uk/hydrology/id/stations/f9fcfbc0-af1b-46f6-bf20-6d8aedc1c72f",
#                 "RLOIid": "3121",
#                 "label": "GRIBBLEFORD BRIDGE",
#                 "stationReference": "50121",
#                 "wiskiID": "SS50F007"
#             },
#             "unit": {
#                 "@id": "http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond"
#             },
#             "unitName": "m3/s",
#             "valueStatistic": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/mean",
#                 "label": "mean"
#             }
#         },
#         {
#             "@id": "http://environment.data.gov.uk/hydrology/id/measures/5ea01221-9252-4e29-b92c-9b452255b5be-flow--i-15_min-m3_s-measured",
#             "label": "Measured flow 15 min timeseries for Baggs Mill",
#             "notation": "5ea01221-9252-4e29-b92c-9b452255b5be-flow--i-15_min-m3_s-measured",
#             "observationType": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/Measured",
#                 "label": "Measured"
#             },
#             "observedProperty": {
#                 "@id": "http://environment.data.gov.uk/reference/def/op/waterFlow",
#                 "label": "Water Flow"
#             },
#             "parameter": "flow",
#             "parameterName": "Flow",
#             "period": 900,
#             "station": {
#                 "@id": "http://environment.data.gov.uk/hydrology/id/stations/5ea01221-9252-4e29-b92c-9b452255b5be",
#                 "label": "Baggs Mill",
#                 "wiskiID": "444510"
#             },
#             "unit": {
#                 "@id": "http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond"
#             },
#             "unitName": "m3/s",
#             "valueStatistic": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/mean",
#                 "label": "mean"
#             }
#         },
#         {
#             "@id": "http://environment.data.gov.uk/hydrology/id/measures/SS93F030-flow-m-86400-m3s-qualified",
#             "label": "Qualified daily mean flow timeseries for SS93F030(BESSOM BRIDGE)",
#             "notation": "SS93F030-flow-m-86400-m3s-qualified",
#             "observationType": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/Qualified",
#                 "label": "Qualified"
#             },
#             "observedProperty": {
#                 "@id": "http://environment.data.gov.uk/reference/def/op/waterFlow",
#                 "label": "Water Flow"
#             },
#             "parameter": "flow",
#             "parameterName": "Flow",
#             "period": 86400,
#             "station": {
#                 "@id": "http://environment.data.gov.uk/hydrology/id/stations/SS93F030",
#                 "label": "BESSOM BRIDGE",
#                 "wiskiID": "SS93F030"
#             },
#             "unit": {
#                 "@id": "http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond"
#             },
#             "unitName": "m3/s",
#             "valueStatistic": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/mean",
#                 "label": "mean"
#             }
#         },
#         {
#             "@id": "http://environment.data.gov.uk/hydrology/id/measures/SS92F057-flow-m-86400-m3s-qualified",
#             "label": "Qualified daily mean flow timeseries for SS92F057(UPTON (TRIB))",
#             "notation": "SS92F057-flow-m-86400-m3s-qualified",
#             "observationType": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/Qualified",
#                 "label": "Qualified"
#             },
#             "observedProperty": {
#                 "@id": "http://environment.data.gov.uk/reference/def/op/waterFlow",
#                 "label": "Water Flow"
#             },
#             "parameter": "flow",
#             "parameterName": "Flow",
#             "period": 86400,
#             "station": {
#                 "@id": "http://environment.data.gov.uk/hydrology/id/stations/SS92F057",
#                 "label": "UPTON (TRIB)",
#                 "wiskiID": "SS92F057"
#             },
#             "unit": {
#                 "@id": "http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond"
#             },
#             "unitName": "m3/s",
#             "valueStatistic": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/mean",
#                 "label": "mean"
#             }
#         },
#         {
#             "@id": "http://environment.data.gov.uk/hydrology/id/measures/SS92F056-flow-m-86400-m3s-qualified",
#             "label": "Qualified daily mean flow timeseries for SS92F056(UPTON)",
#             "notation": "SS92F056-flow-m-86400-m3s-qualified",
#             "observationType": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/Qualified",
#                 "label": "Qualified"
#             },
#             "observedProperty": {
#                 "@id": "http://environment.data.gov.uk/reference/def/op/waterFlow",
#                 "label": "Water Flow"
#             },
#             "parameter": "flow",
#             "parameterName": "Flow",
#             "period": 86400,
#             "station": {
#                 "@id": "http://environment.data.gov.uk/hydrology/id/stations/SS92F056",
#                 "label": "UPTON",
#                 "wiskiID": "SS92F056"
#             },
#             "unit": {
#                 "@id": "http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond"
#             },
#             "unitName": "m3/s",
#             "valueStatistic": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/mean",
#                 "label": "mean"
#             }
#         },
#         {
#             "@id": "http://environment.data.gov.uk/hydrology/id/measures/SS92F051-flow-m-86400-m3s-qualified",
#             "label": "Qualified daily mean flow timeseries for SS92F051(WIMBLEBALL FOOTBRIDGE)",
#             "notation": "SS92F051-flow-m-86400-m3s-qualified",
#             "observationType": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/Qualified",
#                 "label": "Qualified"
#             },
#             "observedProperty": {
#                 "@id": "http://environment.data.gov.uk/reference/def/op/waterFlow",
#                 "label": "Water Flow"
#             },
#             "parameter": "flow",
#             "parameterName": "Flow",
#             "period": 86400,
#             "station": {
#                 "@id": "http://environment.data.gov.uk/hydrology/id/stations/SS92F051",
#                 "label": "WIMBLEBALL FOOTBRIDGE",
#                 "wiskiID": "SS92F051"
#             },
#             "unit": {
#                 "@id": "http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond"
#             },
#             "unitName": "m3/s",
#             "valueStatistic": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/mean",
#                 "label": "mean"
#             }
#         },
#         {
#             "@id": "http://environment.data.gov.uk/hydrology/id/measures/530176-flow-m-86400-m3s-qualified",
#             "label": "Qualified daily mean flow timeseries for 530176(BRADFORD ON AVON GS)",
#             "notation": "530176-flow-m-86400-m3s-qualified",
#             "observationType": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/Qualified",
#                 "label": "Qualified"
#             },
#             "observedProperty": {
#                 "@id": "http://environment.data.gov.uk/reference/def/op/waterFlow",
#                 "label": "Water Flow"
#             },
#             "parameter": "flow",
#             "parameterName": "Flow",
#             "period": 86400,
#             "station": {
#                 "@id": "http://environment.data.gov.uk/hydrology/id/stations/530176",
#                 "label": "BRADFORD ON AVON GS",
#                 "wiskiID": "530176"
#             },
#             "unit": {
#                 "@id": "http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond"
#             },
#             "unitName": "m3/s",
#             "valueStatistic": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/mean",
#                 "label": "mean"
#             }
#         },
#         {
#             "@id": "http://environment.data.gov.uk/hydrology/id/measures/432610-flow-m-86400-m3s-qualified",
#             "label": "Qualified daily mean flow timeseries for 432610(EAST MILLS FLUME)",
#             "notation": "432610-flow-m-86400-m3s-qualified",
#             "observationType": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/Qualified",
#                 "label": "Qualified"
#             },
#             "observedProperty": {
#                 "@id": "http://environment.data.gov.uk/reference/def/op/waterFlow",
#                 "label": "Water Flow"
#             },
#             "parameter": "flow",
#             "parameterName": "Flow",
#             "period": 86400,
#             "station": {
#                 "@id": "http://environment.data.gov.uk/hydrology/id/stations/432610",
#                 "label": "EAST MILLS FLUME",
#                 "wiskiID": "432610"
#             },
#             "unit": {
#                 "@id": "http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond"
#             },
#             "unitName": "m3/s",
#             "valueStatistic": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/mean",
#                 "label": "mean"
#             }
#         },
#         {
#             "@id": "http://environment.data.gov.uk/hydrology/id/measures/445509-flow-m-86400-m3s-qualified",
#             "label": "Qualified daily mean flow timeseries for 445509(LOUDSMILL FISHPASS)",
#             "notation": "445509-flow-m-86400-m3s-qualified",
#             "observationType": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/Qualified",
#                 "label": "Qualified"
#             },
#             "observedProperty": {
#                 "@id": "http://environment.data.gov.uk/reference/def/op/waterFlow",
#                 "label": "Water Flow"
#             },
#             "parameter": "flow",
#             "parameterName": "Flow",
#             "period": 86400,
#             "station": {
#                 "@id": "http://environment.data.gov.uk/hydrology/id/stations/445509",
#                 "label": "LOUDSMILL FISHPASS",
#                 "wiskiID": "445509"
#             },
#             "unit": {
#                 "@id": "http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond"
#             },
#             "unitName": "m3/s",
#             "valueStatistic": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/mean",
#                 "label": "mean"
#             }
#         },
#         {
#             "@id": "http://environment.data.gov.uk/hydrology/id/measures/445510-flow-m-86400-m3s-qualified",
#             "label": "Qualified daily mean flow timeseries for 445510(LOUDSMILL NOT INCLUDING FISHPASS)",
#             "notation": "445510-flow-m-86400-m3s-qualified",
#             "observationType": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/Qualified",
#                 "label": "Qualified"
#             },
#             "observedProperty": {
#                 "@id": "http://environment.data.gov.uk/reference/def/op/waterFlow",
#                 "label": "Water Flow"
#             },
#             "parameter": "flow",
#             "parameterName": "Flow",
#             "period": 86400,
#             "station": {
#                 "@id": "http://environment.data.gov.uk/hydrology/id/stations/445510",
#                 "label": "LOUDSMILL NOT INCLUDING FISHPASS",
#                 "wiskiID": "445510"
#             },
#             "unit": {
#                 "@id": "http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond"
#             },
#             "unitName": "m3/s",
#             "valueStatistic": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/mean",
#                 "label": "mean"
#             }
#         },
#         {
#             "@id": "http://environment.data.gov.uk/hydrology/id/measures/BRIGHR-flow-m-900-m3s-qualified",
#             "label": "Qualified daily mean flow timeseries for BRIGHR(BRIGHTLINGSEA RG (TELEM))",
#             "notation": "BRIGHR-flow-m-900-m3s-qualified",
#             "observationType": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/Qualified",
#                 "label": "Qualified"
#             },
#             "observedProperty": {
#                 "@id": "http://environment.data.gov.uk/reference/def/op/waterFlow",
#                 "label": "Water Flow"
#             },
#             "parameter": "flow",
#             "parameterName": "Flow",
#             "period": 900,
#             "station": {
#                 "@id": "http://environment.data.gov.uk/hydrology/id/stations/BRIGHR",
#                 "label": "BRIGHTLINGSEA RG (TELEM)",
#                 "wiskiID": "BRIGHR"
#             },
#             "unit": {
#                 "@id": "http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond"
#             },
#             "unitName": "m3/s",
#             "valueStatistic": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/mean",
#                 "label": "mean"
#             }
#         },
#         {
#             "@id": "http://environment.data.gov.uk/hydrology/id/measures/90888236-flow-m-900-m3s-qualified",
#             "label": "Qualified daily mean flow timeseries for 90888236(DIDMARTON 1)",
#             "notation": "90888236-flow-m-900-m3s-qualified",
#             "observationType": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/Qualified",
#                 "label": "Qualified"
#             },
#             "observedProperty": {
#                 "@id": "http://environment.data.gov.uk/reference/def/op/waterFlow",
#                 "label": "Water Flow"
#             },
#             "parameter": "flow",
#             "parameterName": "Flow",
#             "period": 900,
#             "station": {
#                 "@id": "http://environment.data.gov.uk/hydrology/id/stations/90888236",
#                 "label": "DIDMARTON 1",
#                 "wiskiID": "90888236"
#             },
#             "unit": {
#                 "@id": "http://qudt.org/1.1/vocab/unit#CubicMeterPerSecond"
#             },
#             "unitName": "m3/s",
#             "valueStatistic": {
#                 "@id": "http://environment.data.gov.uk/reference/def/core/mean",
#                 "label": "mean"
#             }
#         }
#     ],
#     "meta": {
#         "@id": "http://environment.data.gov.uk/hydrology/id/measures",
#         "comment": "Test version of hydrology API, alpha",
#         "hasFormat": [
#             "http://environment.data.gov.uk/hydrology/id/measures.ttl",
#             "http://environment.data.gov.uk/hydrology/id/measures.geojson",
#             "http://environment.data.gov.uk/hydrology/id/measures.csv",
#             "http://environment.data.gov.uk/hydrology/id/measures.rdf",
#             "http://environment.data.gov.uk/hydrology/id/measures.html"
#         ],
#         "license": "http://www.nationalarchives.gov.uk/doc/open-government-licence/version/3/",
#         "licenseName": "OGL 3",
#         "publisher": "Environment Agency",
#         "version": "0.2.0"
#     }
# }

# %%
# Query API based on location easting and northing
# points near Hull 503907 , 435465
# format of parameters for API
# params = [easting={x}&northing={y}&dist={d}]

# %%
# Obtain available stations
local = requests.get('http://environment.data.gov.uk/hydrology/id/stations?easting=435465&northing=503907&dist=100000')

# %%
local.status_code
# Out:
# 200

# %%
# This provides an empty csv of stations within 10000m of easting and northing point - this feature may not be working
print(json.dumps(local.json(), sort_keys=True, indent = 4))
# Out:
# {
#     "items": [],
#     "meta": {
#         "@id": "http://environment.data.gov.uk/hydrology/id/stations?easting=435465&northing=503907&dist=100000",
#         "comment": "Test version of hydrology API, alpha",
#         "hasFormat": [
#             "http://environment.data.gov.uk/hydrology/id/stations.rdf?dist=100000&easting=435465&northing=503907",
#             "http://environment.data.gov.uk/hydrology/id/stations.csv?dist=100000&easting=435465&northing=503907",
#             "http://environment.data.gov.uk/hydrology/id/stations.ttl?dist=100000&easting=435465&northing=503907",
#             "http://environment.data.gov.uk/hydrology/id/stations.geojson?dist=100000&easting=435465&northing=503907",
#             "http://environment.data.gov.uk/hydrology/id/stations.html?dist=100000&easting=435465&northing=503907"
#         ],
#         "license": "http://www.nationalarchives.gov.uk/doc/open-government-licence/version/3/",
#         "licenseName": "OGL 3",
#         "publisher": "Environment Agency",
#         "version": "0.2.0"
#     }
# }

# %% [markdown]
# ## Using the flood-monitoring API
# https://environment.data.gov.uk/hydrology/doc/reference

# %%
# EA Flood API
url = 'http://environment.data.gov.uk/flood-monitoring/id/stations?dist=20&easting=503907&northing=435465'

# %%
flood = requests.get(url)

# %%
flood
# Out:
# <Response [200]>

# %%
# Check data in database, seems to be just river levels
flood.json().get('items')
# Out:
# [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3404',
#   'RLOIid': '8333',
#   'catchmentName': 'Hull and East Riding',
#   'dateOpened': '1998-03-17',
#   'easting': 485267,
#   'gridReference': 'SE8526731219',
#   'label': 'North America',
#   'lat': 53.77033,
#   'long': -0.707786,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/L3404-level-stage-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Stage',
#     'unitName': 'mAOD'}],
#   'northing': 431219,
#   'notation': 'L3404',
#   'riverName': 'Market Weighton Canal',
#   'stageScale': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3404/stageScale',
#   'stationReference': 'L3404',
#   'status': 'http://environment.data.gov.uk/flood-monitoring/def/core/statusActive',
#   'town': 'North America',
#   'wiskiID': 'L3404'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/F3316',
#   'RLOIid': '8239',
#   'catchmentName': 'Hull and East Riding',
#   'dateOpened': '2001-03-02',
#   'easting': 522485,
#   'label': 'Burstwick Hall Road Bridge',
#   'lat': 53.739921,
#   'long': -0.144398,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/F3316-level-stage-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Stage',
#     'unitName': 'mAOD'}],
#   'northing': 428659,
#   'notation': 'F3316',
#   'riverName': 'Burstwick Drain',
#   'stageScale': 'http://environment.data.gov.uk/flood-monitoring/id/stations/F3316/stageScale',
#   'stationReference': 'F3316',
#   'status': 'http://environment.data.gov.uk/flood-monitoring/def/core/statusActive',
#   'town': 'Burstwick',
#   'wiskiID': 'L3316'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3211',
#   'RLOIid': '8338',
#   'catchmentName': 'Hull and East Riding',
#   'dateOpened': '1996-03-31',
#   'datumOffset': -0.059,
#   'downstageScale': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3211/downstageScale',
#   'easting': 503431,
#   'gridReference': 'TA 0343525872',
#   'label': 'Hessle',
#   'lat': 53.719075,
#   'long': -0.434087,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/L3211-level-downstage-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Downstream Stage',
#     'unitName': 'mAOD'},
#    {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/L3211-level-downstage-i-15_min-mASD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Downstream Stage',
#     'unitName': 'mASD'},
#    {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/L3211-level-stage-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Stage',
#     'unitName': 'mAOD'},
#    {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/L3211-level-stage-i-15_min-mASD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Stage',
#     'unitName': 'mASD'}],
#   'northing': 425880,
#   'notation': 'L3211',
#   'riverName': 'Fleet Drain',
#   'stageScale': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3211/stageScale',
#   'stationReference': 'L3211',
#   'status': 'http://environment.data.gov.uk/flood-monitoring/def/core/statusActive',
#   'town': 'Hessle',
#   'wiskiID': 'L3211'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/E1442',
#   'RLOIid': '6012',
#   'catchmentName': 'Grimsby and Ancholme',
#   'dateOpened': '1995-01-01',
#   'easting': 497500,
#   'label': 'South Ferriby',
#   'lat': 53.677267,
#   'long': -0.525433,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/E1442-level-tidal_level-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Tidal Level',
#     'unitName': 'mAOD'}],
#   'northing': 421100,
#   'notation': 'E1442',
#   'riverName': 'Tide',
#   'stageScale': 'http://environment.data.gov.uk/flood-monitoring/id/stations/E1442/stageScale',
#   'stationReference': 'E1442',
#   'status': 'http://environment.data.gov.uk/flood-monitoring/def/core/statusActive',
#   'town': 'Ferriby Sluice',
#   'wiskiID': 'T29006'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3203',
#   'RLOIid': '8103',
#   'catchmentName': 'Hull and East Riding',
#   'dateOpened': '1996-03-30',
#   'easting': 510200,
#   'label': 'Hull Barrier Victoria Pier',
#   'lat': 53.739883,
#   'long': -0.330677,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/L3203-level-downstage-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Downstream Stage',
#     'unitName': 'mAOD'},
#    {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/L3203-level-stage-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Stage',
#     'unitName': 'mAOD'},
#    {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/L3203-level-tidal_level-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Tidal Level',
#     'unitName': 'mAOD'}],
#   'northing': 428350,
#   'notation': 'L3203',
#   'riverName': 'River Hull',
#   'stageScale': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3203/stageScale',
#   'stationReference': 'L3203',
#   'status': 'http://environment.data.gov.uk/flood-monitoring/def/core/statusActive',
#   'town': 'Kingston Upon Hull',
#   'wiskiID': 'L3203'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3491',
#   'RLOIid': '8036',
#   'catchmentName': 'Hull and East Riding',
#   'dateOpened': '1996-03-31',
#   'easting': 493400,
#   'label': 'Brough',
#   'lat': 53.727084,
#   'long': -0.585836,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/L3491-level-tidal_level-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Tidal Level',
#     'unitName': 'mAOD'}],
#   'northing': 426561,
#   'notation': 'L3491',
#   'riverName': 'Brough Clough',
#   'stageScale': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3491/stageScale',
#   'stationReference': 'L3491',
#   'status': 'http://environment.data.gov.uk/flood-monitoring/def/core/statusActive',
#   'town': 'Brough',
#   'wiskiID': 'L3491'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/F3480',
#   'RLOIid': '8238',
#   'catchmentName': 'Hull and East Riding',
#   'dateOpened': '1986-01-01',
#   'easting': 489000,
#   'label': 'North Cave',
#   'lat': 53.77313,
#   'long': -0.651055,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/F3480-level-stage-i-15_min-m',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Stage',
#     'unitName': 'm'}],
#   'northing': 431600,
#   'notation': 'F3480',
#   'riverName': 'Mires Beck',
#   'stageScale': 'http://environment.data.gov.uk/flood-monitoring/id/stations/F3480/stageScale',
#   'stationReference': 'F3480',
#   'status': 'http://environment.data.gov.uk/flood-monitoring/def/core/statusActive',
#   'town': 'North Cave',
#   'wiskiID': 'F3480'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3204',
#   'RLOIid': '8281',
#   'catchmentName': 'Hull and East Riding',
#   'dateOpened': '1996-03-10',
#   'easting': 505397,
#   'gridReference': 'TA0539739744',
#   'label': 'Beverley Shipyard',
#   'lat': 53.843243,
#   'long': -0.399574,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/L3204-level-stage-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Stage',
#     'unitName': 'mAOD'}],
#   'northing': 439744,
#   'notation': 'L3204',
#   'riverName': 'River Hull',
#   'stageScale': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3204/stageScale',
#   'stationReference': 'L3204',
#   'status': 'http://environment.data.gov.uk/flood-monitoring/def/core/statusActive',
#   'town': 'Beverley',
#   'wiskiID': 'L3204'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/E1151',
#   'easting': 511990,
#   'gridReference': 'TA1199025430',
#   'label': 'GOXHILL OUTFALL SLUICE',
#   'lat': 53.713268,
#   'long': -0.304607,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/E1151-level-stage-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Stage',
#     'unitName': 'mAOD'},
#    {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/E1151-level-stage-i-15_min-mASD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Stage',
#     'unitName': 'mASD'}],
#   'northing': 425430,
#   'notation': 'E1151',
#   'stationReference': 'E1151'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3311',
#   'RLOIid': '8336',
#   'catchmentName': 'Hull and East Riding',
#   'dateOpened': '1996-03-31',
#   'easting': 516844,
#   'gridReference': 'TA1684427811',
#   'label': 'Salt end',
#   'lat': 53.733596,
#   'long': -0.230199,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/L3311-level-stage-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Stage',
#     'unitName': 'mAOD'}],
#   'northing': 427811,
#   'notation': 'L3311',
#   'riverName': 'Burstwick Drain',
#   'stageScale': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3311/stageScale',
#   'stationReference': 'L3311',
#   'status': 'http://environment.data.gov.uk/flood-monitoring/def/core/statusActive',
#   'town': 'Hull',
#   'wiskiID': 'L3311'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/E1435',
#   'RLOIid': '6242',
#   'catchmentName': 'Grimsby and Ancholme',
#   'dateOpened': '1996-09-09',
#   'datumOffset': 1.5,
#   'easting': 503030,
#   'label': 'Barton on Humber',
#   'lat': 53.689056,
#   'long': -0.441274,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/E1435-level-stage-i-15_min-mASD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Stage',
#     'unitName': 'mASD'}],
#   'northing': 422530,
#   'notation': 'E1435',
#   'riverName': 'Barton Haven',
#   'stageScale': 'http://environment.data.gov.uk/flood-monitoring/id/stations/E1435/stageScale',
#   'stationReference': 'E1435',
#   'status': 'http://environment.data.gov.uk/flood-monitoring/def/core/statusActive',
#   'town': 'Barton-Upon-Humber',
#   'wiskiID': 'L29032'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3206',
#   'easting': 510002,
#   'gridReference': 'TA1000229672',
#   'label': 'Hull High Flags',
#   'lat': 53.751801,
#   'long': -0.333208,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/L3206-level-stage-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Stage',
#     'unitName': 'mAOD'}],
#   'northing': 429672,
#   'notation': 'L3206',
#   'stationReference': 'L3206'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3313',
#   'RLOIid': '8237',
#   'catchmentName': 'Hull and East Riding',
#   'dateOpened': '2001-01-12',
#   'easting': 519050,
#   'label': 'Hedon Thorn Road Bridge',
#   'lat': 53.735693,
#   'long': -0.196665,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/L3313-level-stage-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Stage',
#     'unitName': 'mAOD'}],
#   'northing': 428100,
#   'notation': 'L3313',
#   'riverName': 'Burstwick Drain',
#   'stageScale': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3313/stageScale',
#   'stationReference': 'L3313',
#   'status': 'http://environment.data.gov.uk/flood-monitoring/def/core/statusActive',
#   'town': 'Hedon',
#   'wiskiID': 'L3313'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3401',
#   'RLOIid': '8334',
#   'catchmentName': 'Hull and East Riding',
#   'dateOpened': '1996-03-31',
#   'easting': 487422,
#   'gridReference': 'SE8742225623',
#   'label': 'Broomfleet Weighton Lock',
#   'lat': 53.71969,
#   'long': -0.67668,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/L3401-level-stage-i-15_min----',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Stage',
#     'unitName': '---'},
#    {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/L3401-level-stage-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Stage',
#     'unitName': 'mAOD'}],
#   'northing': 425623,
#   'notation': 'L3401',
#   'riverName': 'Weighton Lock',
#   'stageScale': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3401/stageScale',
#   'stationReference': 'L3401',
#   'status': 'http://environment.data.gov.uk/flood-monitoring/def/core/statusActive',
#   'town': 'Broomfleet',
#   'wiskiID': 'L3401'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3314',
#   'RLOIid': '8337',
#   'catchmentName': 'Hull and East Riding',
#   'dateOpened': '2006-07-13',
#   'easting': 518160,
#   'gridReference': 'TA1816028103',
#   'label': 'Hedon Westlands Drain',
#   'lat': 53.735923,
#   'long': -0.210149,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/L3314-level-1-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': '1',
#     'unitName': 'mAOD'},
#    {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/L3314-level-stage-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Stage',
#     'unitName': 'mAOD'}],
#   'northing': 428103,
#   'notation': 'L3314',
#   'riverName': 'Burstwick Drain',
#   'stageScale': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3314/stageScale',
#   'stationReference': 'L3314',
#   'status': 'http://environment.data.gov.uk/flood-monitoring/def/core/statusActive',
#   'town': 'Hedon',
#   'wiskiID': 'L3314'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L24012',
#   'RLOIid': '8024',
#   'catchmentName': 'Hull and East Riding',
#   'dateOpened': '1996-03-31',
#   'easting': 484200,
#   'label': 'Blacktoft',
#   'lat': 53.707432,
#   'long': -0.725879,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/L24012-level-stage-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Stage',
#     'unitName': 'mAOD'}],
#   'northing': 424200,
#   'notation': 'L24012',
#   'riverName': 'River Ouse',
#   'stageScale': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L24012/stageScale',
#   'stationReference': 'L24012',
#   'status': 'http://environment.data.gov.uk/flood-monitoring/def/core/statusActive',
#   'town': 'Blacktoft',
#   'wiskiID': 'L24012'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/E71139',
#   'RLOIid': '6008',
#   'catchmentName': 'England - East Coast',
#   'dateOpened': '2012-02-03',
#   'easting': 519959,
#   'gridReference': 'TA 1996 1638',
#   'label': 'Immingham',
#   'lat': 53.63018,
#   'long': -0.18742,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/E71139-level-tidal_level-Mean-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Tidal Level',
#     'unitName': 'mAOD'}],
#   'northing': 416378,
#   'notation': 'E71139',
#   'riverName': 'Tide',
#   'stageScale': 'http://environment.data.gov.uk/flood-monitoring/id/stations/E71139/stageScale',
#   'stationReference': 'E71139',
#   'status': 'http://environment.data.gov.uk/flood-monitoring/def/core/statusActive',
#   'town': 'Grimsby',
#   'wiskiID': 'E5697'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/E71124',
#   'easting': 519959,
#   'gridReference': 'TA 19959 16382',
#   'label': 'Immingham',
#   'lat': 53.63022,
#   'long': -0.18742,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/E71124-level-tidal_level-Mean-15_min-m',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Tidal Level',
#     'unitName': 'm'}],
#   'northing': 416382,
#   'notation': 'E71124',
#   'stationReference': 'E71124'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/4088',
#   'easting': 484238,
#   'gridReference': 'SE8423824156',
#   'label': 'Blacktoft MGX TL',
#   'lat': 53.707031,
#   'long': -0.725316,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/4088-level-stage-i-15_min-mASD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Stage',
#     'unitName': 'mASD'}],
#   'northing': 424156,
#   'notation': '4088',
#   'stationReference': '4088'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3360',
#   'easting': 519947,
#   'gridReference': 'TA1994716402',
#   'label': 'Immingham',
#   'lat': 53.630398,
#   'long': -0.187592,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/L3360-level-tidal_level-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Tidal Level',
#     'unitName': 'mAOD'}],
#   'northing': 416402,
#   'notation': 'L3360',
#   'stationReference': 'L3360'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/E1152',
#   'RLOIid': '9051',
#   'catchmentName': 'Grimsby and Ancholme',
#   'dateOpened': '1998-01-19',
#   'easting': 511990,
#   'gridReference': 'TA11992543',
#   'label': 'Goxhill',
#   'lat': 53.713268,
#   'long': -0.304607,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/E1152-level-tidal_level-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Tidal Level',
#     'unitName': 'mAOD'}],
#   'northing': 425430,
#   'notation': 'E1152',
#   'riverName': 'Tide',
#   'stageScale': 'http://environment.data.gov.uk/flood-monitoring/id/stations/E1152/stageScale',
#   'stationReference': 'E1152',
#   'status': 'http://environment.data.gov.uk/flood-monitoring/def/core/statusActive',
#   'town': 'Goxhill',
#   'wiskiID': 'T29009'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3230',
#   'RLOIid': '8335',
#   'catchmentName': 'Hull and East Riding',
#   'dateOpened': '1996-03-31',
#   'easting': 509998,
#   'gridReference': 'TA0999829679',
#   'label': 'Hull High Flaggs, Lincoln Street',
#   'lat': 53.751865,
#   'long': -0.333266,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/L3230-level-stage-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Stage',
#     'unitName': 'mAOD'}],
#   'northing': 429679,
#   'notation': 'L3230',
#   'riverName': 'River Hull',
#   'stageScale': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3230/stageScale',
#   'stationReference': 'L3230',
#   'status': 'http://environment.data.gov.uk/flood-monitoring/def/core/statusActive',
#   'town': 'Hull',
#   'wiskiID': 'L3206'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3241',
#   'RLOIid': '8382',
#   'catchmentName': 'Hull and East Riding',
#   'dateOpened': '1998-01-27',
#   'easting': 513097,
#   'gridReference': 'TA1309729300',
#   'label': 'East Hull Hedon Road',
#   'lat': 53.747798,
#   'long': -0.286429,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/L3241-level-stage-i-15_min----',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Stage',
#     'unitName': '---'},
#    {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/L3241-level-stage-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Stage',
#     'unitName': 'mAOD'}],
#   'northing': 429300,
#   'notation': 'L3241',
#   'riverName': 'Holderness Drain',
#   'stageScale': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3241/stageScale',
#   'stationReference': 'L3241',
#   'status': 'http://environment.data.gov.uk/flood-monitoring/def/core/statusActive',
#   'town': 'East Hull Hedon Road',
#   'wiskiID': 'L3241'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3208',
#   'RLOIid': '9367',
#   'catchmentName': 'Hull and East Riding',
#   'dateOpened': '2000-04-13',
#   'easting': 510153,
#   'gridReference': 'TA1015331427',
#   'label': 'Stoneferry Bridge',
#   'lat': 53.767537,
#   'long': -0.330293,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/L3208-level-stage-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Stage',
#     'unitName': 'mAOD'}],
#   'northing': 431427,
#   'notation': 'L3208',
#   'riverName': 'River Hull',
#   'stageScale': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3208/stageScale',
#   'stationReference': 'L3208',
#   'status': 'http://environment.data.gov.uk/flood-monitoring/def/core/statusActive',
#   'town': 'Stoneferry Bridge',
#   'wiskiID': 'L3208'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3207',
#   'easting': 505692,
#   'gridReference': 'TA0569239284',
#   'label': 'Waterside PS',
#   'lat': 53.83905,
#   'long': -0.39525,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/L3207-level-stage-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Stage',
#     'unitName': 'mAOD'}],
#   'northing': 439284,
#   'notation': 'L3207',
#   'stationReference': 'L3207'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3250',
#   'RLOIid': '9383',
#   'catchmentName': 'Hull and East Riding',
#   'dateOpened': '1996-03-30',
#   'easting': 510665,
#   'gridReference': 'TA1066543388',
#   'label': 'Riston Pumping Station',
#   'lat': 53.874886,
#   'long': -0.318231,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/L3250-level-downstage-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Downstream Stage',
#     'unitName': 'mAOD'}],
#   'northing': 443388,
#   'notation': 'L3250',
#   'riverName': 'Monk Dyke',
#   'stageScale': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3250/stageScale',
#   'stationReference': 'L3250',
#   'status': 'http://environment.data.gov.uk/flood-monitoring/def/core/statusActive',
#   'town': 'Riston Pumping Station',
#   'wiskiID': 'L3250'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/F3120',
#   'easting': 509358,
#   'gridReference': 'TA0935854867',
#   'label': 'Foston Mill',
#   'lat': 53.97829,
#   'long': -0.334,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/F3120-level-stage-i-15_min-m',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Stage',
#     'unitName': 'm'}],
#   'northing': 454867,
#   'notation': 'F3120',
#   'stationReference': 'F3120'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3246',
#   'RLOIid': '8383',
#   'catchmentName': 'Hull and East Riding',
#   'dateOpened': '1996-03-30',
#   'easting': 507443,
#   'gridReference': 'TA0744342495',
#   'label': 'Tickton PS',
#   'lat': 53.86754,
#   'long': -0.367529,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/L3246-level-stage-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Stage',
#     'unitName': 'mAOD'}],
#   'northing': 442495,
#   'notation': 'L3246',
#   'riverName': 'Holderness Drain',
#   'stageScale': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3246/stageScale',
#   'stationReference': 'L3246',
#   'status': 'http://environment.data.gov.uk/flood-monitoring/def/core/statusActive',
#   'town': 'Tickton PS',
#   'wiskiID': 'L3246'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3243',
#   'easting': 511442,
#   'gridReference': 'TA1144235578',
#   'label': 'Bransholme Gt Culvert PS',
#   'lat': 53.804556,
#   'long': -0.309248,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/L3243-level-downstage-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Downstream Stage',
#     'unitName': 'mAOD'},
#    {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/L3243-level-stage-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Stage',
#     'unitName': 'mAOD'}],
#   'northing': 435578,
#   'notation': 'L3243',
#   'stationReference': 'L3243'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/AN-SFRB',
#   'easting': 497500,
#   'gridReference': 'SE9750021100',
#   'label': 'FERRIBY SLUICE AUTOMATION',
#   'lat': 53.67726711598593,
#   'long': -0.5254325379496286,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/AN-SFRB-level-tidal_level-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Tidal Level',
#     'unitName': 'mAOD'}],
#   'northing': 421100,
#   'notation': 'AN-SFRB',
#   'stationReference': 'AN-SFRB'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/AN-GOX',
#   'easting': 512000,
#   'gridReference': 'TA1200025500',
#   'label': 'GOXHILL OUTFALL SLUICE',
#   'lat': 53.71389482128164,
#   'long': -0.3044302262076623,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/AN-GOX-level-tidal_level-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Tidal Level',
#     'unitName': 'mAOD'}],
#   'northing': 425500,
#   'notation': 'AN-GOX',
#   'stationReference': 'AN-GOX'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3205',
#   'RLOIid': '8381',
#   'catchmentName': 'Hull and East Riding',
#   'dateOpened': '1996-03-30',
#   'easting': 506211,
#   'gridReference': 'TA0621147044',
#   'label': 'Wilfholme PS Hull Level',
#   'lat': 53.908662,
#   'long': -0.384682,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/L3205-level-stage-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Stage',
#     'unitName': 'mAOD'}],
#   'northing': 447044,
#   'notation': 'L3205',
#   'riverName': 'River Hull',
#   'stageScale': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3205/stageScale',
#   'stationReference': 'L3205',
#   'status': 'http://environment.data.gov.uk/flood-monitoring/def/core/statusActive',
#   'town': 'Wilfholme PS',
#   'wiskiID': 'L3205'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3320',
#   'RLOIid': '8378',
#   'catchmentName': 'Hull and East Riding',
#   'dateOpened': '1997-04-23',
#   'easting': 516516,
#   'gridReference': 'TA1651626331',
#   'label': 'Paull',
#   'lat': 53.720373,
#   'long': -0.235726,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/L3320-level-stage-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Stage',
#     'unitName': 'mAOD'}],
#   'northing': 426331,
#   'notation': 'L3320',
#   'riverName': 'North Sea',
#   'stageScale': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3320/stageScale',
#   'stationReference': 'L3320',
#   'status': 'http://environment.data.gov.uk/flood-monitoring/def/core/statusActive',
#   'town': 'Paull',
#   'wiskiID': 'L3320'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3331',
#   'RLOIid': '8379',
#   'catchmentName': 'Hull and East Riding',
#   'dateOpened': '1996-03-30',
#   'easting': 523621,
#   'gridReference': 'TA2362118972',
#   'label': 'Stone Creek',
#   'lat': 53.652632,
#   'long': -0.131044,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/L3331-level-downstage-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Downstream Stage',
#     'unitName': 'mAOD'},
#    {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/L3331-level-stage-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Stage',
#     'unitName': 'mAOD'}],
#   'northing': 418972,
#   'notation': 'L3331',
#   'riverName': 'Keyingham Drain',
#   'stageScale': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3331/stageScale',
#   'stationReference': 'L3331',
#   'status': 'http://environment.data.gov.uk/flood-monitoring/def/core/statusActive',
#   'town': 'Stone Creek',
#   'wiskiID': 'L3331'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3231',
#   'RLOIid': '8380',
#   'catchmentName': 'Hull and East Riding',
#   'dateOpened': '1996-03-30',
#   'easting': 506211,
#   'gridReference': 'TA0621147044',
#   'label': 'Wilfholme PS',
#   'lat': 53.908662,
#   'long': -0.384682,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/L3231-level-stage-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Stage',
#     'unitName': 'mAOD'}],
#   'northing': 447044,
#   'notation': 'L3231',
#   'riverName': 'Beverley and Barmston Drain',
#   'stageScale': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3231/stageScale',
#   'stationReference': 'L3231',
#   'status': 'http://environment.data.gov.uk/flood-monitoring/def/core/statusActive',
#   'town': 'Wilfholme PS',
#   'wiskiID': 'L3231'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3112',
#   'RLOIid': '8384',
#   'catchmentName': 'Hull and East Riding',
#   'dateOpened': '1996-11-16',
#   'easting': 509450,
#   'gridReference': 'TA0945049443',
#   'label': 'Hempholme Pumping Station Roam Drain',
#   'lat': 53.929542,
#   'long': -0.334541,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/L3112-level-stage-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Stage',
#     'unitName': 'mAOD'}],
#   'northing': 449443,
#   'notation': 'L3112',
#   'riverName': 'Roam Drain',
#   'stageScale': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3112/stageScale',
#   'stationReference': 'L3112',
#   'status': 'http://environment.data.gov.uk/flood-monitoring/def/core/statusActive',
#   'town': 'Hempholme Pumping Station Roam Drain',
#   'wiskiID': 'L3112'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/F3102',
#   'RLOIid': '8385',
#   'catchmentName': 'Hull and East Riding',
#   'dateOpened': '2008-09-04',
#   'easting': 507957,
#   'gridReference': 'TA0795749913',
#   'label': 'Hempholme Weir',
#   'lat': 53.934077,
#   'long': -0.357103,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/F3102-level-2-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': '2',
#     'unitName': 'mAOD'}],
#   'northing': 449913,
#   'notation': 'F3102',
#   'riverName': 'River Hull',
#   'stageScale': 'http://environment.data.gov.uk/flood-monitoring/id/stations/F3102/stageScale',
#   'stationReference': 'F3102',
#   'status': 'http://environment.data.gov.uk/flood-monitoring/def/core/statusActive',
#   'town': 'Hempholme Weir',
#   'wiskiID': 'F3102'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L32014_NE',
#   'RLOIid': '8373',
#   'catchmentName': 'Hull and East Riding',
#   'dateOpened': '2011-03-07',
#   'easting': 503295,
#   'gridReference': 'TA0329527583',
#   'label': 'Hessle Western Drain',
#   'lat': 53.734403,
#   'long': -0.435579,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/L32014_NE-level-stage-i-15_min-m',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Stage',
#     'unitName': 'm'}],
#   'northing': 427583,
#   'notation': 'L32014_NE',
#   'riverName': 'Fleet Drain',
#   'stageScale': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L32014_NE/stageScale',
#   'stationReference': 'L32014_NE',
#   'status': 'http://environment.data.gov.uk/flood-monitoring/def/core/statusActive',
#   'town': 'Hessle Western Drain',
#   'wiskiID': 'L32014_NE'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/E1555',
#   'RLOIid': '9052',
#   'catchmentName': 'Grimsby and Ancholme',
#   'dateOpened': '2002-02-01',
#   'easting': 508025,
#   'label': 'New Holland',
#   'lat': 53.704256,
#   'long': -0.365039,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/E1555-level-tidal_level-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Tidal Level',
#     'unitName': 'mAOD'}],
#   'northing': 424334,
#   'notation': 'E1555',
#   'riverName': 'Tide',
#   'stageScale': 'http://environment.data.gov.uk/flood-monitoring/id/stations/E1555/stageScale',
#   'stationReference': 'E1555',
#   'status': 'http://environment.data.gov.uk/flood-monitoring/def/core/statusActive',
#   'wiskiID': 'T29050'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/E45871',
#   'easting': 497550,
#   'gridReference': 'SE975210',
#   'label': 'Rainfall station',
#   'lat': 53.676809,
#   'long': -0.524692,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/E45871-rainfall-tipping_bucket_raingauge-t-15_min-mm',
#     'parameter': 'rainfall',
#     'parameterName': 'Rainfall',
#     'period': 900,
#     'qualifier': 'Tipping Bucket Raingauge',
#     'unitName': 'mm'}],
#   'northing': 421050,
#   'notation': 'E45871',
#   'stationReference': 'E45871'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/041238',
#   'easting': 507450,
#   'gridReference': 'TA074424',
#   'label': 'Rainfall station',
#   'lat': 53.867134,
#   'long': -0.367439,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/041238-rainfall-tipping_bucket_raingauge-t-15_min-mm',
#     'parameter': 'rainfall',
#     'parameterName': 'Rainfall',
#     'period': 900,
#     'qualifier': 'Tipping Bucket Raingauge',
#     'unitName': 'mm'}],
#   'northing': 442450,
#   'notation': '041238',
#   'stationReference': '041238'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/041917',
#   'easting': 511450,
#   'gridReference': 'TA114356',
#   'label': 'Rainfall station',
#   'lat': 53.805201,
#   'long': -0.309101,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/041917-rainfall-tipping_bucket_raingauge-t-15_min-mm',
#     'parameter': 'rainfall',
#     'parameterName': 'Rainfall',
#     'period': 900,
#     'qualifier': 'Tipping Bucket Raingauge',
#     'unitName': 'mm'}],
#   'northing': 435650,
#   'notation': '041917',
#   'stationReference': '041917'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/E1645',
#   'easting': 509550,
#   'gridReference': 'TA095199',
#   'label': 'Rainfall station',
#   'lat': 53.664551,
#   'long': -0.343494,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/E1645-rainfall-tipping_bucket_raingauge-t-15_min-mm',
#     'parameter': 'rainfall',
#     'parameterName': 'Rainfall',
#     'period': 900,
#     'qualifier': 'Tipping Bucket Raingauge',
#     'unitName': 'mm'}],
#   'northing': 419950,
#   'notation': 'E1645',
#   'stationReference': 'E1645'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/046222',
#   'easting': 487450,
#   'gridReference': 'SE874256',
#   'label': 'Rainfall station',
#   'lat': 53.719928,
#   'long': -0.676248,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/046222-rainfall-tipping_bucket_raingauge-t-15_min-mm',
#     'parameter': 'rainfall',
#     'parameterName': 'Rainfall',
#     'period': 900,
#     'qualifier': 'Tipping Bucket Raingauge',
#     'unitName': 'mm'}],
#   'northing': 425650,
#   'notation': '046222',
#   'stationReference': '046222'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/_L32014_NE',
#   'easting': 503507,
#   'gridReference': 'TA0350727628',
#   'label': 'Hessle Western Drain',
#   'lat': 53.734766,
#   'long': -0.432351,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/_L32014_NE-level-stage-i-15_min-m',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Stage',
#     'unitName': 'm'}],
#   'northing': 427628,
#   'notation': '_L32014_NE',
#   'stationReference': '_L32014_NE'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/F3402',
#   'RLOIid': '9147',
#   'catchmentName': 'Hull and East Riding',
#   'dateOpened': '1989-01-01',
#   'easting': 484462,
#   'gridReference': 'SE8446234397',
#   'label': 'Wholsea Grange',
#   'lat': 53.799018,
#   'long': -0.719127,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/F3402-level-stage-i-15_min-m',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Stage',
#     'unitName': 'm'}],
#   'northing': 434397,
#   'notation': 'F3402',
#   'riverName': 'Back Delfin',
#   'stageScale': 'http://environment.data.gov.uk/flood-monitoring/id/stations/F3402/stageScale',
#   'stationReference': 'F3402',
#   'status': 'http://environment.data.gov.uk/flood-monitoring/def/core/statusActive',
#   'town': 'Wholsea Grange',
#   'wiskiID': 'F3402'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3408',
#   'RLOIid': '9359',
#   'catchmentName': 'Hull and East Riding',
#   'dateOpened': '2010-03-24',
#   'easting': 487873,
#   'gridReference': 'SE8787342068',
#   'label': 'Market Weighton',
#   'lat': 53.867381,
#   'long': -0.665165,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/L3408-level-stage-i-15_min-m',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Stage',
#     'unitName': 'm'}],
#   'northing': 442068,
#   'notation': 'L3408',
#   'riverName': 'Mill Beck',
#   'stageScale': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3408/stageScale',
#   'stationReference': 'L3408',
#   'status': 'http://environment.data.gov.uk/flood-monitoring/def/core/statusActive',
#   'town': 'Market Weighton',
#   'wiskiID': 'L3408'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3402',
#   'RLOIid': '9360',
#   'catchmentName': 'Hull and East Riding',
#   'dateOpened': '2003-11-17',
#   'easting': 496296,
#   'gridReference': 'SE9629624617',
#   'label': 'Brough West Clough',
#   'lat': 53.709091,
#   'long': -0.542562,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/L3402-level-stage-i-15_min----',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Stage',
#     'unitName': '---'},
#    {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/L3402-level-stage-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Stage',
#     'unitName': 'mAOD'}],
#   'northing': 424617,
#   'notation': 'L3402',
#   'riverName': 'West Clough',
#   'stageScale': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3402/stageScale',
#   'stationReference': 'L3402',
#   'status': 'http://environment.data.gov.uk/flood-monitoring/def/core/statusActive',
#   'town': 'Brough West Clough',
#   'wiskiID': 'L3402'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3130',
#   'RLOIid': '9362',
#   'catchmentName': 'Hull and East Riding',
#   'dateOpened': '2000-04-22',
#   'easting': 509017,
#   'gridReference': 'TA0901753743',
#   'label': 'Frodingham Bridge',
#   'lat': 53.968264,
#   'long': -0.339599,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/L3130-level-stage-i-15_min-m',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Stage',
#     'unitName': 'm'}],
#   'northing': 453743,
#   'notation': 'L3130',
#   'riverName': 'Frodingham Beck',
#   'stageScale': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3130/stageScale',
#   'stationReference': 'L3130',
#   'status': 'http://environment.data.gov.uk/flood-monitoring/def/core/statusActive',
#   'town': 'Frodingham Bridge',
#   'wiskiID': 'L3130'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3121',
#   'RLOIid': '9363',
#   'catchmentName': 'Hull and East Riding',
#   'dateOpened': '1997-01-01',
#   'easting': 507856,
#   'gridReference': ['TA0785650595', 'TA0785650603'],
#   'label': ['Scurf Dyke', 'Scurf Dyke Dyke Level'],
#   'lat': [53.940225, 53.940297],
#   'long': [-0.358398, -0.358401],
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/L3121-level-stage-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Stage',
#     'unitName': 'mAOD'}],
#   'northing': [450595, 450603],
#   'notation': 'L3121',
#   'riverName': 'Scurf Dyke',
#   'stageScale': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3121/stageScale',
#   'stationReference': 'L3121',
#   'status': 'http://environment.data.gov.uk/flood-monitoring/def/core/statusActive',
#   'town': 'Scurf Dyke Dyke Level',
#   'wiskiID': 'L3121'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3109',
#   'RLOIid': '9364',
#   'catchmentName': 'Hull and East Riding',
#   'dateOpened': '1997-01-01',
#   'easting': 507859,
#   'gridReference': 'TA0785950595',
#   'label': 'Scurf Dyke (Hull Level)',
#   'lat': 53.940225,
#   'long': -0.358355,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/L3109-level-stage-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Stage',
#     'unitName': 'mAOD'}],
#   'northing': 450595,
#   'notation': 'L3109',
#   'riverName': 'River Hull',
#   'stageScale': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3109/stageScale',
#   'stationReference': 'L3109',
#   'status': 'http://environment.data.gov.uk/flood-monitoring/def/core/statusActive',
#   'town': 'Scurf Dyke (Hull Level)',
#   'wiskiID': 'L3109'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L32011',
#   'RLOIid': '9366',
#   'catchmentName': 'Hull and East Riding',
#   'dateOpened': '2003-05-15',
#   'easting': 508191,
#   'gridReference': 'TA0819134303',
#   'label': 'Dunswell Ennerdale Bridge',
#   'lat': 53.793786,
#   'long': -0.359038,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/L32011-level-stage-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Stage',
#     'unitName': 'mAOD'}],
#   'northing': 434303,
#   'notation': 'L32011',
#   'riverName': 'River Hull',
#   'stageScale': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L32011/stageScale',
#   'stationReference': 'L32011',
#   'status': 'http://environment.data.gov.uk/flood-monitoring/def/core/statusActive',
#   'town': 'Dunswell Ennerdale Bridge',
#   'wiskiID': 'L32011_NE'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3330',
#   'RLOIid': '9368',
#   'catchmentName': 'Hull and East Riding',
#   'dateOpened': '2003-08-11',
#   'easting': 517714,
#   'gridReference': 'TA1771425301',
#   'label': 'Thorngumbald Pumping Station',
#   'lat': 53.710851,
#   'long': -0.217971,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/L3330-level-stage-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Stage',
#     'unitName': 'mAOD'}],
#   'northing': 425301,
#   'notation': 'L3330',
#   'riverName': 'Thorngumbald Drain',
#   'stageScale': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3330/stageScale',
#   'stationReference': 'L3330',
#   'status': 'http://environment.data.gov.uk/flood-monitoring/def/core/statusActive',
#   'town': 'Thorngumbald Pumping Station',
#   'wiskiID': 'L3330'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3111',
#   'RLOIid': '9378',
#   'catchmentName': 'Hull and East Riding',
#   'dateOpened': '1996-11-16',
#   'downstageScale': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3111/downstageScale',
#   'easting': 509441,
#   'gridReference': 'TA0944149447',
#   'label': 'Hempholme Pumping Station',
#   'lat': 53.92958,
#   'long': -0.334677,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/L3111-level-downstage-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Downstream Stage',
#     'unitName': 'mAOD'},
#    {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/L3111-level-stage-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Stage',
#     'unitName': 'mAOD'}],
#   'northing': 449447,
#   'notation': 'L3111',
#   'riverName': 'Mickley Dyke',
#   'stageScale': 'http://environment.data.gov.uk/flood-monitoring/id/stations/L3111/stageScale',
#   'stationReference': 'L3111',
#   'status': 'http://environment.data.gov.uk/flood-monitoring/def/core/statusActive',
#   'town': 'Hempholme Pumping Station Mickley Dyke',
#   'wiskiID': 'L3111'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/E1001',
#   'easting': 506380,
#   'gridReference': 'TA0638022620',
#   'label': 'BARROW HAVEN OUTFALL SLUICE',
#   'lat': 53.689194,
#   'long': -0.390535,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/E1001-level-stage-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Stage',
#     'unitName': 'mAOD'}],
#   'northing': 422620,
#   'notation': 'E1001',
#   'stationReference': 'E1001'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/E1810',
#   'easting': 497585,
#   'gridReference': 'SE9758520968',
#   'label': 'FERRIBY SLUICE  EAST DRAIN OUTFALL',
#   'lat': 53.676065,
#   'long': -0.524188,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/E1810-level-stage-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Stage',
#     'unitName': 'mAOD'}],
#   'northing': 420968,
#   'notation': 'E1810',
#   'stationReference': 'E1810'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/E1105',
#   'easting': 514454,
#   'gridReference': 'TA1445422874',
#   'label': 'EAST HALTON SKITTER SLUICE',
#   'lat': 53.689771,
#   'long': -0.268234,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/E1105-level-stage-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Stage',
#     'unitName': 'mAOD'}],
#   'northing': 422874,
#   'notation': 'E1105',
#   'stationReference': 'E1105'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/E1236',
#   'easting': 496772,
#   'gridReference': 'SE9677218102',
#   'label': 'SCABCROFT WEIR SLUICE AUTOMATIC HORKSTOW',
#   'lat': 53.650465,
#   'long': -0.537383,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/E1236-level-stage-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Stage',
#     'unitName': 'mAOD'}],
#   'northing': 418102,
#   'notation': 'E1236',
#   'stationReference': 'E1236'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/E4960',
#   'easting': 516520,
#   'gridReference': 'TA1652020010',
#   'label': 'NORTH KILLINGHOLME OUTFALL',
#   'lat': 53.663585,
#   'long': -0.238038,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/E4960-level-stage-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Stage',
#     'unitName': 'mAOD'}],
#   'northing': 420010,
#   'notation': 'E4960',
#   'stationReference': 'E4960'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/E4906',
#   'easting': 520786,
#   'gridReference': 'TA2078615733',
#   'label': 'HABROUGH MARSH DRAIN OUTFALL IMMINGHAM',
#   'lat': 53.624195,
#   'long': -0.175171,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/E4906-level-stage-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Stage',
#     'unitName': 'mAOD'}],
#   'northing': 415733,
#   'notation': 'E4906',
#   'stationReference': 'E4906'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/E4946',
#   'easting': 508025,
#   'gridReference': 'TA0802524325',
#   'label': 'NEW HOLLAND OUTFALL',
#   'lat': 53.704175,
#   'long': -0.365042,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/E4946-level-stage-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Stage',
#     'unitName': 'mAOD'}],
#   'northing': 424325,
#   'notation': 'E4946',
#   'stationReference': 'E4946'},
#  {'@id': 'http://environment.data.gov.uk/flood-monitoring/id/stations/E1318',
#   'easting': 493436,
#   'gridReference': 'SE9343622797',
#   'label': 'WINTERTON BECK OUTFALL SLUICE WINTERINGHAM',
#   'lat': 53.693257,
#   'long': -0.586425,
#   'measures': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/id/measures/E1318-level-stage-i-15_min-mAOD',
#     'parameter': 'level',
#     'parameterName': 'Water Level',
#     'period': 900,
#     'qualifier': 'Stage',
#     'unitName': 'mAOD'}],
#   'northing': 422797,
#   'notation': 'E1318',
#   'stationReference': 'E1318'}]
